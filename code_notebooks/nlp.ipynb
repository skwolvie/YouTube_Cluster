# %%
import re
import pandas as pd
from scipy.cluster.hierarchy import linkage, fcluster
from sklearn.feature_extraction.text import TfidfVectorizer
from transformers import AutoTokenizer, AutoModel
from sentence_transformers import SentenceTransformer
import torch
from sklearn.cluster import AgglomerativeClustering

# %%
# Load the data into a pandas dataframe
df = pd.read_csv("../data/final_data.csv")
df.columns
# Out:
# Index(['channel_id', 'channel_title', 'video_topics', 'corpus_text'], dtype='object')

# %%
# Text cleaning
df['corpus_text'] = df['corpus_text'].str.lower()
df['corpus_text'] = df['corpus_text'].apply(lambda x: re.sub('[^\w\s]', '', x))
df['corpus_text'] = df['corpus_text'].apply(lambda x: re.sub('\d+', '', x))

# %%
model= SentenceTransformer("sentence-transformers/all-mpnet-base-v2")
# Out:
# Downloading (…)a8e1d/.gitattributes:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading (…)_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading (…)b20bca8e1d/README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# Downloading (…)0bca8e1d/config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# Downloading (…)ce_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading (…)e1d/data_config.json:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading (…)"pytorch_model.bin";:   0%|          | 0.00/438M [00:00<?, ?B/s]
# Downloading (…)nce_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Downloading (…)a8e1d/tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# Downloading (…)8e1d/train_script.py:   0%|          | 0.00/13.1k [00:00<?, ?B/s]
# Downloading (…)b20bca8e1d/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)bca8e1d/modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]

# %%
"""
This is a simple application for sentence embeddings: clustering

Sentences are mapped to sentence embeddings and then agglomerative clustering with a threshold is applied.
"""
from sentence_transformers import SentenceTransformer
from sklearn.cluster import AgglomerativeClustering
import numpy as np

embedder = SentenceTransformer('all-mpnet-base-v2')
corpus= df['corpus_text'].to_list()
corpus_embeddings = embedder.encode(corpus)

# Normalize the embeddings to unit length
corpus_embeddings = corpus_embeddings /  np.linalg.norm(corpus_embeddings, axis=1, keepdims=True)

# Perform kmean clustering
clustering_model = AgglomerativeClustering(n_clusters=None, distance_threshold=1.5, affinity='euclidean', linkage='ward') #, affinity='cosine', linkage='average', distance_threshold=0.4)
clustering_model.fit(corpus_embeddings)
cluster_assignment = clustering_model.labels_

clustered_sentences = {}
for sentence_id, cluster_id in enumerate(cluster_assignment):
    if cluster_id not in clustered_sentences:
        clustered_sentences[cluster_id] = []

    clustered_sentences[cluster_id].append(corpus[sentence_id])

for i, cluster in clustered_sentences.items():
    print("Cluster ", i)
    print("")
# Out:
# Cluster  19
#
# Cluster  26
#
# Cluster  28
#
# Cluster  20
#
# Cluster  29
#
# Cluster  23
#
# Cluster  21
#
# Cluster  30
#
# Cluster  15
#
# Cluster  11
#
# Cluster  18
#
# Cluster  2
#
# Cluster  5
#
# Cluster  16
#
# Cluster  12
#
# Cluster  32
#
# Cluster  7
#
# Cluster  9
#
# Cluster  10
#
# Cluster  0
#
# Cluster  24
#
# Cluster  14
#
# Cluster  8
#
# Cluster  3
#
# Cluster  13
#
# Cluster  31
#
# Cluster  22
#
# Cluster  1
#
# Cluster  33
#
# Cluster  25
#
# Cluster  4
#
# Cluster  17
#
# Cluster  6
#
# Cluster  27

# %%
df['cluster']=cluster_assignment
df['cluster'].value_counts()
# Out:
# 2     24
# 0     22
# 8     21
# 14    19
# 30    18
# 19    17
# 3     17
# 1     15
# 11    14
# 13    13
# 9     13
# 7     12
# 5     12
# 18    11
# 6     11
# 23    10
# 29     9
# 20     9
# 26     9
# 33     9
# 15     8
# 21     8
# 16     7
# 17     7
# 28     7
# 10     6
# 32     5
# 25     4
# 4      4
# 31     4
# 22     4
# 24     4
# 12     3
# 27     3
# Name: cluster, dtype: int64

# %%
# Generate a name for the cluster labels
tfidf = TfidfVectorizer(stop_words='english')
tfidf_matrix = tfidf.fit_transform(df['corpus_text'])

def get_cluster_keywords(cluster_id):
    cluster_rows = df[df['cluster'] == cluster_id]
    cluster_tfidf = tfidf_matrix[cluster_rows.index]
    sums = np.array(cluster_tfidf.sum(axis=0)).ravel()
    sorted_indices = np.argsort(sums)[::-1]
    feature_names = np.array(tfidf.get_feature_names())
    keywords = feature_names[sorted_indices[:5]]
    return ', '.join(keywords)

df['cluster_name'] = df['cluster'].apply(lambda x: get_cluster_keywords(x))
# Out:
# /Users/sk/miniforge3/lib/python3.10/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
pd.DataFrame(df[['cluster_name', 'channel_title', 'channel_id']]).head(20)
# Out:
#                                          cluster_name         channel_title  \
# 0                      job, shorts, career, work, iit          Joshua Fluke
# 1   subliminal, affirmations, meditation, mind, hy...     30 Minute Mindset
# 2   startup, design, entrepreneurship, startups, s...             The Futur
# 3                  usa, abroad, dallas, student, visa                Yocket
# 4           healing, attraction, law, shivani, pranic          Clark Kegley
# 5                echosmith, shuba, ed, music, sheeran       Reneé Dominique
# 6                ukraine, russia, news, tldr, chomsky      TLDR News Global
# 7                kannada, comedy, funny, vines, prank       Dhruv Actoholic
# 8                echosmith, shuba, ed, music, sheeran            Ed Sheeran
# 9               documentary, telegraph, bbc, tv, news               eltrece
# 10              documentary, telegraph, bbc, tv, news  60 Minutes Australia
# 11           prank, shorts, onlyjayus, iphone, vrchat           Karl Conrad
# 12        data, science, learning, google, tensorflow         Roaring Kitty
# 13               kannada, comedy, funny, vines, prank           Tanmay Bhat
# 14        data, science, learning, google, tensorflow            TensorFlow
# 15                  songs, song, music, cover, mishra           Saif Hassan
# 16                  mantra, bhajan, shiva, durga, sai      Strumm Spiritual
# 17                gre, toefl, ielts, test, vocabulary       Joshua Emmanuel
# 18       vending, stradman, cars, collection, machine           TheStradman
# 19          healing, attraction, law, shivani, pranic         SynchroShakti
#
#                   channel_id
# 0   UC-91UA-Xy2Cvb98deRXuggA
# 1   UC-UYJe8O87Y9Qo3XJQRDljg
# 2   UC-b3c7kxa5vU-bnmaROgvog
# 3   UC-cDK8t9TBFWEnCyoTYIR-Q
# 4   UC-dmJ79518WlKMbsu50eMTQ
# 5   UC-fn57_xqMv-PaMmpm-ZspQ
# 6   UC-uhvujip5deVcEtLxnW8qg
# 7   UC-vGXUq70B4p6BD-z-711hQ
# 8   UC0C-w0YjGpqDXGB8IHb662A
# 9   UC0DM_mHV2u6dj8ig51GkQwg
# 10  UC0L1suV8pVgO4pCAIBNGx5w
# 11  UC0MYNOsIrz6jmXfIMERyRHQ
# 12  UC0patpmwYbhcEUap0bTX3JQ
# 13  UC0rE2qq81of4fojo-KhO5rg
# 14  UC0rqucBdTuFTjJiefW5t-IQ
# 15  UC101sGN0S49Ig2eq6Wd6kRA
# 16  UC1DdFzHNvp2Vv86vyi46MNA
# 17  UC1S4Jeodbr5EbsCOIgBWJPQ
# 18  UC21Kozr_K0yDM-VjoihG9Aw
# 19  UC22B9hVNit3v7nOhxsK6wVQ

# %%
len(df['cluster'].unique())

# %%
df['cluster'].unique()
# Out:
# array([19, 26, 28, 20, 29, 23, 21, 30, 15, 11, 18,  2,  5, 16, 12, 32,  7,
#         9, 10,  0, 24, 14,  8,  3, 13, 31, 22,  1, 33, 25,  4, 17,  6, 27])

# %%
for i in df['cluster'].unique():
    print(i)
    print(df[df['cluster']==i]['cluster_name'].tolist()[0])
# Out:
# 19
# job, shorts, career, work, iit
# 26
# subliminal, affirmations, meditation, mind, hypnosis
# 28
# startup, design, entrepreneurship, startups, sales
# 20
# usa, abroad, dallas, student, visa
# 29
# healing, attraction, law, shivani, pranic
# 23
# echosmith, shuba, ed, music, sheeran
# 21
# ukraine, russia, news, tldr, chomsky
# 30
# kannada, comedy, funny, vines, prank
# 15
# documentary, telegraph, bbc, tv, news
# 11
# prank, shorts, onlyjayus, iphone, vrchat
# 18
# data, science, learning, google, tensorflow
# 2
# songs, song, music, cover, mishra
# 5
# mantra, bhajan, shiva, durga, sai
# 16
# gre, toefl, ielts, test, vocabulary
# 12
# vending, stradman, cars, collection, machine
# 32
# product, management, marketing, sales, carey
# 7
# workout, fitness, healthy, calisthenics, dr
# 9
# dubai, amish, dignity, nas, zaidalit
# 10
# peterson, jordan, personality, psychology, clips
# 0
# english, study, big, harvard, brown
# 24
# sbi, rachana, market, ca, card
# 14
# comedy, trevor, noah, funny, netflix
# 8
# india, sadhguru, google, canada, indian
# 3
# bloomberg, news, bitcoin, economy, economics
# 13
# vice, documentary, news, history, world
# 31
# homeopathic, medicine, homeopathy, rsverma, dr
# 22
# dating, gabblin, hussey, men, relationship
# 1
# india, defence, indian, upsc, ias
# 33
# python, google, dash, software, programming
# 25
# kold, animals, kolder, tides, shifting
# 4
# quantum, holes, flammy, integral, interpretation
# 17
# shooting, gun, glock, review, ak
# 6
# music, guitar, berklee, ukulele, flute
# 27
# immigration, card, green, visa, hb

# %%
df[df['cluster_name']=="dating, gabblin, hussey, men, relationship"]
# Out:
#                    channel_id                   channel_title  \
# 59   UC9HGzFGt7BLmWDqooUbWGBg                  Matthew Hussey
# 67   UCB_oqEMvs9Xd7RKoG_8sCyA                         Gabblin
# 213  UCZC45sBWNdkqSQ9Bwtt5lfA                      Anna Akana
# 283  UCnpB6UZ7U5rKPLEjCHKLgbg  LoveQuest With Lisa Concepcion
#
#                                           video_topics  \
# 59   , Health, Lifestyle_(sociology), Entertainment...
# 67        , Lifestyle_(sociology), Entertainment, Film
# 213      , Music, Lifestyle_(sociology), Entertainment
# 283                    , Health, Lifestyle_(sociology)
#
#                                            corpus_text  cluster  \
# 59   matthew hussey worlds leading dating advice ex...       22
# 67   tell stories help live authentically broke wed...       22
# 213  actor writer director management coronel group...       22
# 283  entertaining uplifting real raw unscripted aut...       22
#
#                                    cluster_name
# 59   dating, gabblin, hussey, men, relationship
# 67   dating, gabblin, hussey, men, relationship
# 213  dating, gabblin, hussey, men, relationship
# 283  dating, gabblin, hussey, men, relationship

# %%
df[df['corpus_text'].str.contains('sports')]
# Out:
#                    channel_id         channel_title  \
# 39   UC6MXE0Px3m1aI4vI0pLWzQg             Goal Guys
# 40   UC6n8I1UDTKP1IWjQMg6_TwA               The B1M
# 53   UC8Su5vZCXWRag13H53zWVwA                  TIME
# 63   UCAkYgW-5XG5uPyaO9PD_I5A     Veer by Discovery
# 87   UCG1_A0jPBGZUpRW7XkaaBkg         Honest Outlaw
# 137  UCNJUhkpXnF1GcItcztJM-Ww       Karunesh Talwar
# 148  UCP6HGa63sBC7-KHtkme-p-g             USA TODAY
# 150  UCPgLNge0xqQHWM5B5EFH9Cg         The Telegraph
# 151  UCPxMZIFE856tbTfdkdjzTSQ            BeerBiceps
# 180  UCUMZ7gohGI9HcU9VNsr2FJQ   Bloomberg Originals
# 235  UCd3rCGu_2R_5LN6IcCBHIQA  Green Light Shooting
# 256  UCiT9RITQ9PW6BhXK0y2jaeg               Ken Jee
# 271  UClngPjkNmITx8dkTFV6P0sA            Ram Ghuman
# 288  UCoVwq0vh-XD8RrEyDZ0KeJw          Google India
# 290  UCofLyWKImmSHboaerI4AwfA        Curious Harish
# 303  UCqFzWxSCi39LnW1JKFR3efg   Saturday Night Live
# 340  UCvJJ_dzjViJCoLf5uKUTwoA                  CNBC
# 355  UCy5mW8fB24ITiiC0etjLI6w         Neelesh Misra
#
#                                           video_topics  \
# 39   , Physical_fitness, Sport, Lifestyle_(sociolog...
# 40   , Society, Tourism, Lifestyle_(sociology), Veh...
# 53   , Baseball, Sport, Association_football, Lifes...
# 63                  , Military, Society, Entertainment
# 87                             , Lifestyle_(sociology)
# 137  , Entertainment, Film, Humour, Television_prog...
# 148  , Sport, Politics, Society, Physical_fitness, ...
# 150  , Entertainment, Film, Television_program, Soc...
# 151  , Society, Entertainment, Knowledge, Film, Lif...
# 180  , Society, Food, Lifestyle_(sociology), Techno...
# 235                , Lifestyle_(sociology), Technology
# 256                               , Knowledge, Society
# 271  , Lifestyle_(sociology), Physical_fitness, Health
# 288  , Lifestyle_(sociology), Technology, Society, ...
# 290  , Knowledge, Lifestyle_(sociology), Technology...
# 303  , Entertainment, Film, Performing_arts, Televi...
# 340  , Society, Food, Politics, Vehicle, Action-adv...
# 355  , Entertainment, Film, Television_program, Soc...
#
#                                            corpus_text  cluster  \
# 39   two brothers take different goals fitness prod...       10
# 40   love construction want whole world love hosted...       13
# 53   time brings unparalleled insight access author...       13
# 63   welcome official youtube channel veer discover...        1
# 87   gun reviews people make sure subscribe new cha...       17
# 137  channel videos standup swiggy stand comedy kar...       30
# 148  heartwarming moments latest sports entertainme...       15
# 150  latest news videos opinion pieces animations s...       15
# 151  beerbiceps ranveer allahbadia ultimate selfimp...        8
# 180  bloomberg originals offers bold takes curious ...        3
# 235  welcome green light shooting name chad mostly ...       17
# 256  data science sports analytics passions name ke...       18
# 271  whats going guys let help achieve goals make d...        7
# 288  welcome google indias official youtube channel...        8
# 290  hi im harish cofounder bluelearn accidently go...       19
# 303  welcome official saturday night live channel y...       14
# 340  welcome official youtube channel cnbc wall str...        3
# 355  neelesh misras work reached biggest audio plat...        2
#
#                                          cluster_name
# 39   peterson, jordan, personality, psychology, clips
# 40            vice, documentary, news, history, world
# 53            vice, documentary, news, history, world
# 63                  india, defence, indian, upsc, ias
# 87                   shooting, gun, glock, review, ak
# 137              kannada, comedy, funny, vines, prank
# 148             documentary, telegraph, bbc, tv, news
# 150             documentary, telegraph, bbc, tv, news
# 151           india, sadhguru, google, canada, indian
# 180      bloomberg, news, bitcoin, economy, economics
# 235                  shooting, gun, glock, review, ak
# 256       data, science, learning, google, tensorflow
# 271       workout, fitness, healthy, calisthenics, dr
# 288           india, sadhguru, google, canada, indian
# 290                    job, shorts, career, work, iit
# 303              comedy, trevor, noah, funny, netflix
# 340      bloomberg, news, bitcoin, economy, economics
# 355                 songs, song, music, cover, mishra

# %%
df
# Out:
#                    channel_id                 channel_title  \
# 0    UC-91UA-Xy2Cvb98deRXuggA                  Joshua Fluke
# 1    UC-UYJe8O87Y9Qo3XJQRDljg             30 Minute Mindset
# 2    UC-b3c7kxa5vU-bnmaROgvog                     The Futur
# 3    UC-cDK8t9TBFWEnCyoTYIR-Q                        Yocket
# 4    UC-dmJ79518WlKMbsu50eMTQ                  Clark Kegley
# ..                        ...                           ...
# 354  UCy436qLXlyLqddExVC64auw                Gajendra Verma
# 355  UCy5mW8fB24ITiiC0etjLI6w                 Neelesh Misra
# 356  UCyI4gi0BtlKiUl6KgtuVIUw              CTV Your Morning
# 357  UCydVjjfO74Vr7Scecn1sNAg       Desi American Professor
# 358  UCz8KsDcRFXxzYO4guvCR-LA  Hacking Immigration Law, LLC
#
#                                           video_topics  \
# 0               , Lifestyle_(sociology), Entertainment
# 1                            , Music, Electronic_music
# 2    , Lifestyle_(sociology), Technology, Vehicle, ...
# 3                  , Lifestyle_(sociology), Technology
# 4    , Lifestyle_(sociology), Knowledge, Technology...
# ..                                                 ...
# 354  , Music, Music_of_Asia, Pop_music, Electronic_...
# 355  , Entertainment, Film, Television_program, Soc...
# 356  , Action-adventure_game, Action_game, Country_...
# 357       , Lifestyle_(sociology), Technology, Society
# 358                                          , Society
#
#                                            corpus_text  cluster  \
# 0    make variety content im always wild ideas job ...       19
# 1    welcome little corner youtube im glad find rel...       26
# 2    mission teach billion people make living love ...       28
# 3    yocket indias largest network study abroad asp...       20
# 4    helping create version law attraction reprogra...       29
# ..                                                 ...      ...
# 354  welcome gajendra vermas official youtube chann...        2
# 355  neelesh misras work reached biggest audio plat...        2
# 356  hosted annemarie mediwake coanchors lindsey de...        9
# 357  assistant professor information systems operat...       20
# 358  nan step v step dont wait days marriage based ...       27
#
#                                           cluster_name
# 0                       job, shorts, career, work, iit
# 1    subliminal, affirmations, meditation, mind, hy...
# 2    startup, design, entrepreneurship, startups, s...
# 3                   usa, abroad, dallas, student, visa
# 4            healing, attraction, law, shivani, pranic
# ..                                                 ...
# 354                  songs, song, music, cover, mishra
# 355                  songs, song, music, cover, mishra
# 356               dubai, amish, dignity, nas, zaidalit
# 357                 usa, abroad, dallas, student, visa
# 358                 immigration, card, green, visa, hb
#
# [359 rows x 6 columns]

# %%
for i in df['cluster_name'].unique().tolist():
    print(i)
# Out:
# job, shorts, career, work, iit
# subliminal, affirmations, meditation, mind, hypnosis
# startup, design, entrepreneurship, startups, sales
# usa, abroad, dallas, student, visa
# healing, attraction, law, shivani, pranic
# echosmith, shuba, ed, music, sheeran
# ukraine, russia, news, tldr, chomsky
# kannada, comedy, funny, vines, prank
# documentary, telegraph, bbc, tv, news
# prank, shorts, onlyjayus, iphone, vrchat
# data, science, learning, google, tensorflow
# songs, song, music, cover, mishra
# mantra, bhajan, shiva, durga, sai
# gre, toefl, ielts, test, vocabulary
# vending, stradman, cars, collection, machine
# product, management, marketing, sales, carey
# workout, fitness, healthy, calisthenics, dr
# dubai, amish, dignity, nas, zaidalit
# peterson, jordan, personality, psychology, clips
# english, study, big, harvard, brown
# sbi, rachana, market, ca, card
# comedy, trevor, noah, funny, netflix
# india, sadhguru, google, canada, indian
# bloomberg, news, bitcoin, economy, economics
# vice, documentary, news, history, world
# homeopathic, medicine, homeopathy, rsverma, dr
# dating, gabblin, hussey, men, relationship
# india, defence, indian, upsc, ias
# python, google, dash, software, programming
# kold, animals, kolder, tides, shifting
# quantum, holes, flammy, integral, interpretation
# shooting, gun, glock, review, ak
# music, guitar, berklee, ukulele, flute
# immigration, card, green, visa, hb

# %%
for i in df[df['cluster']==18]['channel_id'].tolist():
    print('https://www.youtube.com/channel/'+i)
# Out:
# https://www.youtube.com/channel/UC0patpmwYbhcEUap0bTX3JQ
# https://www.youtube.com/channel/UC0rqucBdTuFTjJiefW5t-IQ
# https://www.youtube.com/channel/UC8ofcOdHNINiPrBA9D59Vaw
# https://www.youtube.com/channel/UCNU_lfiiWBdtULKOw6X0Dig
# https://www.youtube.com/channel/UCYwVxWpjeKFWwu8TML-Te9A
# https://www.youtube.com/channel/UCiT9RITQ9PW6BhXK0y2jaeg
# https://www.youtube.com/channel/UCk6ONJlPzjw3DohAeMSgsng
# https://www.youtube.com/channel/UCtYLUTtgS3k1Fg4y5tAhLbw
# https://www.youtube.com/channel/UCteRPiisgIoHtMgqHegpWAQ
# https://www.youtube.com/channel/UCupUfUvPVDKDIbDrSFCniAg
# https://www.youtube.com/channel/UCwH7ZUuRVucq4CYIcoAyE4w

# %%
df['channel_url']=df['channel_id'].apply(lambda x: "https://www.youtube.com/channel/"+x)

# %%
df.head()
# Out:
#                  channel_id      channel_title  \
# 0  UC-91UA-Xy2Cvb98deRXuggA       Joshua Fluke
# 1  UC-UYJe8O87Y9Qo3XJQRDljg  30 Minute Mindset
# 2  UC-b3c7kxa5vU-bnmaROgvog          The Futur
# 3  UC-cDK8t9TBFWEnCyoTYIR-Q             Yocket
# 4  UC-dmJ79518WlKMbsu50eMTQ       Clark Kegley
#
#                                         video_topics  \
# 0             , Lifestyle_(sociology), Entertainment
# 1                          , Music, Electronic_music
# 2  , Lifestyle_(sociology), Technology, Vehicle, ...
# 3                , Lifestyle_(sociology), Technology
# 4  , Lifestyle_(sociology), Knowledge, Technology...
#
#                                          corpus_text  cluster  \
# 0  make variety content im always wild ideas job ...       19
# 1  welcome little corner youtube im glad find rel...       26
# 2  mission teach billion people make living love ...       28
# 3  yocket indias largest network study abroad asp...       20
# 4  helping create version law attraction reprogra...       29
#
#                                         cluster_name  \
# 0                     job, shorts, career, work, iit
# 1  subliminal, affirmations, meditation, mind, hy...
# 2  startup, design, entrepreneurship, startups, s...
# 3                 usa, abroad, dallas, student, visa
# 4          healing, attraction, law, shivani, pranic
#
#                                          channel_url
# 0  https://www.youtube.com/channel/UC-91UA-Xy2Cvb...
# 1  https://www.youtube.com/channel/UC-UYJe8O87Y9Q...
# 2  https://www.youtube.com/channel/UC-b3c7kxa5vU-...
# 3  https://www.youtube.com/channel/UC-cDK8t9TBFWE...
# 4  https://www.youtube.com/channel/UC-dmJ79518WlK...

# %%
df[['channel_id', 'channel_url', 'cluster', 'cluster_name']].to_csv('../data/clustered_data.csv')

# %%
import pandas as pd
df= pd.read_csv(r"../data/clustered_data.csv")
df.drop(columns=['Unnamed: 0'], inplace=True)
df
# Out:
#                    channel_id  \
# 0    UC-91UA-Xy2Cvb98deRXuggA
# 1    UC-UYJe8O87Y9Qo3XJQRDljg
# 2    UC-b3c7kxa5vU-bnmaROgvog
# 3    UC-cDK8t9TBFWEnCyoTYIR-Q
# 4    UC-dmJ79518WlKMbsu50eMTQ
# ..                        ...
# 354  UCy436qLXlyLqddExVC64auw
# 355  UCy5mW8fB24ITiiC0etjLI6w
# 356  UCyI4gi0BtlKiUl6KgtuVIUw
# 357  UCydVjjfO74Vr7Scecn1sNAg
# 358  UCz8KsDcRFXxzYO4guvCR-LA
#
#                                            channel_url  cluster  \
# 0    https://www.youtube.com/channel/UC-91UA-Xy2Cvb...       19
# 1    https://www.youtube.com/channel/UC-UYJe8O87Y9Q...       26
# 2    https://www.youtube.com/channel/UC-b3c7kxa5vU-...       28
# 3    https://www.youtube.com/channel/UC-cDK8t9TBFWE...       20
# 4    https://www.youtube.com/channel/UC-dmJ79518WlK...       29
# ..                                                 ...      ...
# 354  https://www.youtube.com/channel/UCy436qLXlyLqd...        2
# 355  https://www.youtube.com/channel/UCy5mW8fB24ITi...        2
# 356  https://www.youtube.com/channel/UCyI4gi0BtlKiU...        9
# 357  https://www.youtube.com/channel/UCydVjjfO74Vr7...       20
# 358  https://www.youtube.com/channel/UCz8KsDcRFXxzY...       27
#
#                                           cluster_name
# 0                       job, shorts, career, work, iit
# 1    subliminal, affirmations, meditation, mind, hy...
# 2    startup, design, entrepreneurship, startups, s...
# 3                   usa, abroad, dallas, student, visa
# 4            healing, attraction, law, shivani, pranic
# ..                                                 ...
# 354                  songs, song, music, cover, mishra
# 355                  songs, song, music, cover, mishra
# 356               dubai, amish, dignity, nas, zaidalit
# 357                 usa, abroad, dallas, student, visa
# 358                 immigration, card, green, visa, hb
#
# [359 rows x 4 columns]

# %%
df.to_csv(r"../data/clustered_data.csv", index=False)

# %%
df.groupby('cluster_name')['channel_url'].apply(list).reset_index(name='links').to_dict('records')
# Out:
# [{'cluster_name': 'bloomberg, news, bitcoin, economy, economics',
#   'links': ['https://www.youtube.com/channel/UC6-URUKHVmFWSt_KdRsX8UA',
#    'https://www.youtube.com/channel/UCGBoWe1mzCvbbqDNncmxm8A',
#    'https://www.youtube.com/channel/UCKQvGU-qtjEthINeViNbn6A',
#    'https://www.youtube.com/channel/UCL8w_A8p8P1HWI3k6PR5Z6w',
#    'https://www.youtube.com/channel/UCLo66QVfEod0nNM_GzKNxmQ',
#    'https://www.youtube.com/channel/UCOa104QrplnxBkVnoArabwQ',
#    'https://www.youtube.com/channel/UCUMZ7gohGI9HcU9VNsr2FJQ',
#    'https://www.youtube.com/channel/UCZ4AMrDcNrfy3X6nsU8-rPg',
#    'https://www.youtube.com/channel/UCZ7x7yDBbEFCGztD8BYvRhA',
#    'https://www.youtube.com/channel/UCdxi8d8qRsRyUi2ERYjYb-w',
#    'https://www.youtube.com/channel/UCi-pkXLbm7sqXFhV1NBLUfQ',
#    'https://www.youtube.com/channel/UCneQdPbDLwZ__ZXP0YVwiag',
#    'https://www.youtube.com/channel/UCnpekFV93kB1O0rVqEKSumg',
#    'https://www.youtube.com/channel/UCo7a6riBFJ3tkeHjvkXPn1g',
#    'https://www.youtube.com/channel/UCqvaXJ1K3HheTPNjH-KpwXQ',
#    'https://www.youtube.com/channel/UCrM7B7SL_g1edFOnmj-SDKg',
#    'https://www.youtube.com/channel/UCvJJ_dzjViJCoLf5uKUTwoA']},
#  {'cluster_name': 'comedy, trevor, noah, funny, netflix',
#   'links': ['https://www.youtube.com/channel/UC59KhIPOR0Jj653dC4laEJw',
#    'https://www.youtube.com/channel/UC8-Th83bH_thdKZDJCrn88g',
#    'https://www.youtube.com/channel/UC8bTQzxgvKkXDAaWkeuUlkg',
#    'https://www.youtube.com/channel/UCG4aUmNL9W0I5hx6Zzp_3-A',
#    'https://www.youtube.com/channel/UCI0xqzZrJdNlnsmzD_Fliiw',
#    'https://www.youtube.com/channel/UCJ0uqCI0Vqr2Rrt1HseGirg',
#    'https://www.youtube.com/channel/UCObk_g1hQBy0RKKriVX_zOQ',
#    'https://www.youtube.com/channel/UCR4wTAyVbbX-IiBiGCgIBTg',
#    'https://www.youtube.com/channel/UCUsN5ZwHx2kILm84-jPDeXw',
#    'https://www.youtube.com/channel/UCYLR1ghzYNyvfjw78raCuxA',
#    'https://www.youtube.com/channel/UCYXhaLEoRfUc34MPSx4HpDw',
#    'https://www.youtube.com/channel/UC_zmsIHN2KoCHI82Cl2S-FA',
#    'https://www.youtube.com/channel/UCarEovlrD9QY-fy-Z6apIDQ',
#    'https://www.youtube.com/channel/UCdWiqyd8RMx_qhCadO19k0g',
#    'https://www.youtube.com/channel/UCpip9EesFuO1lkSY_B-vExw',
#    'https://www.youtube.com/channel/UCqFzWxSCi39LnW1JKFR3efg',
#    'https://www.youtube.com/channel/UCsv4YOF2RBYh0NQ1vuHQ-hg',
#    'https://www.youtube.com/channel/UCw62Qa74SJ4NCdWG3jw7Dfw',
#    'https://www.youtube.com/channel/UCwWhs_6x42TyRM4Wstoq8HA']},
#  {'cluster_name': 'data, science, learning, google, tensorflow',
#   'links': ['https://www.youtube.com/channel/UC0patpmwYbhcEUap0bTX3JQ',
#    'https://www.youtube.com/channel/UC0rqucBdTuFTjJiefW5t-IQ',
#    'https://www.youtube.com/channel/UC8ofcOdHNINiPrBA9D59Vaw',
#    'https://www.youtube.com/channel/UCNU_lfiiWBdtULKOw6X0Dig',
#    'https://www.youtube.com/channel/UCYwVxWpjeKFWwu8TML-Te9A',
#    'https://www.youtube.com/channel/UCiT9RITQ9PW6BhXK0y2jaeg',
#    'https://www.youtube.com/channel/UCk6ONJlPzjw3DohAeMSgsng',
#    'https://www.youtube.com/channel/UCtYLUTtgS3k1Fg4y5tAhLbw',
#    'https://www.youtube.com/channel/UCteRPiisgIoHtMgqHegpWAQ',
#    'https://www.youtube.com/channel/UCupUfUvPVDKDIbDrSFCniAg',
#    'https://www.youtube.com/channel/UCwH7ZUuRVucq4CYIcoAyE4w']},
#  {'cluster_name': 'dating, gabblin, hussey, men, relationship',
#   'links': ['https://www.youtube.com/channel/UC9HGzFGt7BLmWDqooUbWGBg',
#    'https://www.youtube.com/channel/UCB_oqEMvs9Xd7RKoG_8sCyA',
#    'https://www.youtube.com/channel/UCZC45sBWNdkqSQ9Bwtt5lfA',
#    'https://www.youtube.com/channel/UCnpB6UZ7U5rKPLEjCHKLgbg']},
#  {'cluster_name': 'documentary, telegraph, bbc, tv, news',
#   'links': ['https://www.youtube.com/channel/UC0DM_mHV2u6dj8ig51GkQwg',
#    'https://www.youtube.com/channel/UC0L1suV8pVgO4pCAIBNGx5w',
#    'https://www.youtube.com/channel/UCCj956IF62FbT7Gouszaj9w',
#    'https://www.youtube.com/channel/UCIRYBXDze5krPDzAEOxFGVA',
#    'https://www.youtube.com/channel/UCP6HGa63sBC7-KHtkme-p-g',
#    'https://www.youtube.com/channel/UCPgLNge0xqQHWM5B5EFH9Cg',
#    'https://www.youtube.com/channel/UCStOJC8F-Zn_oxeMi2lfQog',
#    'https://www.youtube.com/channel/UCu4XcDBdnZkV6-5z2f16M0g']},
#  {'cluster_name': 'dubai, amish, dignity, nas, zaidalit',
#   'links': ['https://www.youtube.com/channel/UC3Vuq4Q1bKFtAiKYlwRv3oA',
#    'https://www.youtube.com/channel/UC79RWgVZMQa2VOABDPPFvtA',
#    'https://www.youtube.com/channel/UCEIs9nkveW9WmYtsOcJBwTg',
#    'https://www.youtube.com/channel/UCI7-iazJE_CiuVw7_yEpinA',
#    'https://www.youtube.com/channel/UCJX8Wn6opMsBng3QWh0dK6g',
#    'https://www.youtube.com/channel/UCJsUvAqDzczYv2UpFmu4PcA',
#    'https://www.youtube.com/channel/UCKUs5_UjbfEmiPKgEaWH4Rw',
#    'https://www.youtube.com/channel/UCVBXum_ntfgHgHCOYtGOmEw',
#    'https://www.youtube.com/channel/UCVNDbT7AQX7WZMIR2tZdYDg',
#    'https://www.youtube.com/channel/UCZGmXbsgs0cd8NXk6VrF8wQ',
#    'https://www.youtube.com/channel/UC_hoQDD6zKcIqpIYLsFbBeA',
#    'https://www.youtube.com/channel/UChzhFUxUZFAQSJZ_Tp4B1fA',
#    'https://www.youtube.com/channel/UCyI4gi0BtlKiUl6KgtuVIUw']},
#  {'cluster_name': 'echosmith, shuba, ed, music, sheeran',
#   'links': ['https://www.youtube.com/channel/UC-fn57_xqMv-PaMmpm-ZspQ',
#    'https://www.youtube.com/channel/UC0C-w0YjGpqDXGB8IHb662A',
#    'https://www.youtube.com/channel/UC5YEoYuciHpO_0s1Mpz8_JA',
#    'https://www.youtube.com/channel/UCGnsRwFS8Xm13lMAeouzT9g',
#    'https://www.youtube.com/channel/UCJSTwVNFY25vFlnNKwYOKuw',
#    'https://www.youtube.com/channel/UCLeJH3qDdggwMFS6z0I4jbw',
#    'https://www.youtube.com/channel/UCN0Ot_4JS6MiYk4BrT6Sgxw',
#    'https://www.youtube.com/channel/UCOw4v1j3QnzH7X4krQAS7fg',
#    'https://www.youtube.com/channel/UCSZBmDk4v3ozB3kfB2oyUEA',
#    'https://www.youtube.com/channel/UCpPZggubTs5NvcMCHfRCVKw']},
#  {'cluster_name': 'english, study, big, harvard, brown',
#   'links': ['https://www.youtube.com/channel/UC415bOPUcGSamy543abLmRA',
#    'https://www.youtube.com/channel/UC65BYtqlRNjR93D5UxGVfXw',
#    'https://www.youtube.com/channel/UCFPcOxYh3M5Es5KFkieW2Gg',
#    'https://www.youtube.com/channel/UCJKYubtV1bfbhS-SxTm9Z1A',
#    'https://www.youtube.com/channel/UCLyr-hfWVCKHcZjV5fg3jbw',
#    'https://www.youtube.com/channel/UCMV3aTOwUtG5vwfH9_rzb2w',
#    'https://www.youtube.com/channel/UCMwo6hT5hI3R56rO2HYP-wQ',
#    'https://www.youtube.com/channel/UCRRr_xrOm66qaigIbwFLvbQ',
#    'https://www.youtube.com/channel/UCSw5U1MuzDED2Nvlx9m65-Q',
#    'https://www.youtube.com/channel/UCUFFHXvzAMRSD8Bq4bJppxQ',
#    'https://www.youtube.com/channel/UCWo4IA01TXzBeGJJKWHOG9g',
#    'https://www.youtube.com/channel/UCXMVaxrax7RNDPdfRrXXgtQ',
#    'https://www.youtube.com/channel/UCY1kMZp36IQSyNx_9h4mpCg',
#    'https://www.youtube.com/channel/UCYO_jab_esuFRV4b17AJtAw',
#    'https://www.youtube.com/channel/UCfV0_wbjG8KJADuZT2ct4SA',
#    'https://www.youtube.com/channel/UCoOjH8D2XAgjzQlneM2W0EQ',
#    'https://www.youtube.com/channel/UCp9-3fFhiTjcCNxccOJ2vNA',
#    'https://www.youtube.com/channel/UCq1tIu-F5fRVdRZ1DHTXc3Q',
#    'https://www.youtube.com/channel/UCsT0YIqwnpJCM-mx7-gSA4Q',
#    'https://www.youtube.com/channel/UCuJ-WNoWSzB-r43ftlr6gZQ',
#    'https://www.youtube.com/channel/UCuzSOy9pzFbdGsn-aSuMJCA',
#    'https://www.youtube.com/channel/UCvQECJukTDE2i6aCoMnS-Vg']},
#  {'cluster_name': 'gre, toefl, ielts, test, vocabulary',
#   'links': ['https://www.youtube.com/channel/UC1S4Jeodbr5EbsCOIgBWJPQ',
#    'https://www.youtube.com/channel/UCHG1wZgWRqyLscd8xE3d6Ng',
#    'https://www.youtube.com/channel/UCL0ZOT3eKp4RvKcQyBZJ4bw',
#    'https://www.youtube.com/channel/UCSPYtDyppzYF9KMLZ1A-kOw',
#    'https://www.youtube.com/channel/UCZ4sGYJ6l0cgnVNIHY8GY6w',
#    'https://www.youtube.com/channel/UCktwzce9ncy_K78l1KBZkYQ',
#    'https://www.youtube.com/channel/UCra3KQoJlOP7RYwaCyH2qew']},
#  {'cluster_name': 'healing, attraction, law, shivani, pranic',
#   'links': ['https://www.youtube.com/channel/UC-dmJ79518WlKMbsu50eMTQ',
#    'https://www.youtube.com/channel/UC22B9hVNit3v7nOhxsK6wVQ',
#    'https://www.youtube.com/channel/UCE4yfbhDepYoRSAD-tBzJzg',
#    'https://www.youtube.com/channel/UCKzsU94h-PkLBiF5xHo-SjQ',
#    'https://www.youtube.com/channel/UCQdyCrZpGq4Bbu6V8LPUDWg',
#    'https://www.youtube.com/channel/UCYCAYFgoaBn8vzRYXHuTZiA',
#    'https://www.youtube.com/channel/UCa6M_MhZv_NEyXDffvnKikQ',
#    'https://www.youtube.com/channel/UCihUiDJzjyo2ov_qGtW33lw',
#    'https://www.youtube.com/channel/UCu57RDCZ_j0lGUX49fT6khA']},
#  {'cluster_name': 'homeopathic, medicine, homeopathy, rsverma, dr',
#   'links': ['https://www.youtube.com/channel/UC7kbAF7LWIk1pPftd-9ziMw',
#    'https://www.youtube.com/channel/UC9Jxk_mBmLLqOnm61r9EBuw',
#    'https://www.youtube.com/channel/UCCoS6VGcKqYZCdaDHmv30Wg',
#    'https://www.youtube.com/channel/UCxtxloVILDQfbzXnX9iFkQg']},
#  {'cluster_name': 'immigration, card, green, visa, hb',
#   'links': ['https://www.youtube.com/channel/UCVpjKK6JMtlAP3cfBjduTxw',
#    'https://www.youtube.com/channel/UCaROuOh08EiaIqQ8Apka2Yw',
#    'https://www.youtube.com/channel/UCz8KsDcRFXxzYO4guvCR-LA']},
#  {'cluster_name': 'india, defence, indian, upsc, ias',
#   'links': ['https://www.youtube.com/channel/UCAkYgW-5XG5uPyaO9PD_I5A',
#    'https://www.youtube.com/channel/UCBcG9TT58nA1w9Oo3Os3MMg',
#    'https://www.youtube.com/channel/UCFw1xwDebFOyCUKvHo2qRKQ',
#    'https://www.youtube.com/channel/UCGFNZxMqKLsqWERX_N2f08Q',
#    'https://www.youtube.com/channel/UCKZozRVHRYsYHGEyNKuhhdA',
#    'https://www.youtube.com/channel/UCM5RA4WAMWhtX3okNzjWr_w',
#    'https://www.youtube.com/channel/UCQA9tK0nRK1e_Bqg0uETs8A',
#    'https://www.youtube.com/channel/UCS1abmNrZSkWM1vq-sMm63g',
#    'https://www.youtube.com/channel/UCafpueX9hFLls24ed6UddEQ',
#    'https://www.youtube.com/channel/UChIuM0Zpi3WQtV0q91fwXHg',
#    'https://www.youtube.com/channel/UCk85J3pqkn1y--k2wNMbthA',
#    'https://www.youtube.com/channel/UCmXZxX_qexEZxhb5_vQKPCw',
#    'https://www.youtube.com/channel/UCrC8mOqJQpoB7NuIMKIS6rQ',
#    'https://www.youtube.com/channel/UCt2JXOLNxqry7B_4rRZME3Q',
#    'https://www.youtube.com/channel/UCw4wosjC-DKq95xI5klz92w']},
#  {'cluster_name': 'india, sadhguru, google, canada, indian',
#   'links': ['https://www.youtube.com/channel/UC5H_lY2y5X3zhjy5KTez-vQ',
#    'https://www.youtube.com/channel/UC7bCIt-Dk1ZAQIMcdoNmhIQ',
#    'https://www.youtube.com/channel/UC7t4llTRPqj6FeZiDR1Ya_g',
#    'https://www.youtube.com/channel/UCCQSX9nS2WTUrXib2vJN4hA',
#    'https://www.youtube.com/channel/UCCgQaXjsJ6EdFPZeTFQoSyw',
#    'https://www.youtube.com/channel/UCM7UnDj_L5jBnSXpcDWI9tg',
#    'https://www.youtube.com/channel/UCPxMZIFE856tbTfdkdjzTSQ',
#    'https://www.youtube.com/channel/UCRqWqb-iDlueYhUT98Ouj2A',
#    'https://www.youtube.com/channel/UCUKTrXf8KdGIVXudO3dqOWw',
#    'https://www.youtube.com/channel/UCVcIkmIS1R8JM8Xm2ng9_PQ',
#    'https://www.youtube.com/channel/UCaIx0hBYAl-6gl_KjyTgObQ',
#    'https://www.youtube.com/channel/UCcYzLCs3zrQIBVHYA1sK2sw',
#    'https://www.youtube.com/channel/UCioFEhnLd9kNYbdx39ZlxEA',
#    'https://www.youtube.com/channel/UCkGS_3D0HEzfflFnG0bD24A',
#    'https://www.youtube.com/channel/UCl8zB2LZOiLLV0jYUMpTEgA',
#    'https://www.youtube.com/channel/UClwgaGtjn82DV-Spz0N8bFA',
#    'https://www.youtube.com/channel/UCoVwq0vh-XD8RrEyDZ0KeJw',
#    'https://www.youtube.com/channel/UCqhgi4gWXgt66HGTih1u_6g',
#    'https://www.youtube.com/channel/UCsDTy8jvHcwMvSZf_JGi-FA',
#    'https://www.youtube.com/channel/UCsEMQbMruJjM4z6C9xFUbsA',
#    'https://www.youtube.com/channel/UCxfgkOMZRGhW3mGqrAFF-cg']},
#  {'cluster_name': 'job, shorts, career, work, iit',
#   'links': ['https://www.youtube.com/channel/UC-91UA-Xy2Cvb98deRXuggA',
#    'https://www.youtube.com/channel/UC28Nsu2CmbXRD1eGqMVcpYg',
#    'https://www.youtube.com/channel/UC2QhYM2_8ONHsWxkUiS7shQ',
#    'https://www.youtube.com/channel/UC3f6OYvhpV-pmTYgikEbF1g',
#    'https://www.youtube.com/channel/UC4qJ0wpfqPY4PnaNZAuRVuA',
#    'https://www.youtube.com/channel/UC8XKyvQ5Ne_bvYbgv8LaIeg',
#    'https://www.youtube.com/channel/UCH5_L3ytGbBziX0CLuYdQ1Q',
#    'https://www.youtube.com/channel/UCHfYqxApaB6_DXCBuFSYG5w',
#    'https://www.youtube.com/channel/UCM4d4vlR_63WQJv6UxTwZqg',
#    'https://www.youtube.com/channel/UCT4iTe4eB9aRn2p3jRuGlDA',
#    'https://www.youtube.com/channel/UCisy6taOAeLfyaCqcMQDfig',
#    'https://www.youtube.com/channel/UCmem-D5aeCsSRyXTZkH_gKQ',
#    'https://www.youtube.com/channel/UCofLyWKImmSHboaerI4AwfA',
#    'https://www.youtube.com/channel/UCpExuV8qJMfCaSQNL1YG6bQ',
#    'https://www.youtube.com/channel/UCppsTOeeitiiuKIAJcAtEiw',
#    'https://www.youtube.com/channel/UCqZE1WgKgZ9oeICTrov94yQ',
#    'https://www.youtube.com/channel/UCqegMHSWfJy1Mp-GCOiu2qA']},
#  {'cluster_name': 'kannada, comedy, funny, vines, prank',
#   'links': ['https://www.youtube.com/channel/UC-vGXUq70B4p6BD-z-711hQ',
#    'https://www.youtube.com/channel/UC0rE2qq81of4fojo-KhO5rg',
#    'https://www.youtube.com/channel/UC4aTcVTewbHtLeV8eK3enwA',
#    'https://www.youtube.com/channel/UC7C-v-OEqBE641x6SsveaGA',
#    'https://www.youtube.com/channel/UC7eHZXheF8nVOfwB2PEslMw',
#    'https://www.youtube.com/channel/UCAmGmNMwqMNzIC-a6iOLagg',
#    'https://www.youtube.com/channel/UCHQ6ijQ15cDKyqnD-aDf__g',
#    'https://www.youtube.com/channel/UCIRgg5VeGBSdnFy15eao8uQ',
#    'https://www.youtube.com/channel/UCLPHopoiGPUwr8JHpXxBQ9A',
#    'https://www.youtube.com/channel/UCNJUhkpXnF1GcItcztJM-Ww',
#    'https://www.youtube.com/channel/UCNn6AaHharXIbkRleXGboiQ',
#    'https://www.youtube.com/channel/UCQ93iDLSWgc_7o4AOHxkn8Q',
#    'https://www.youtube.com/channel/UCRsVdVQlP6iNhRZLbzhSMBw',
#    'https://www.youtube.com/channel/UCYc3JNvtOfwHWU_DSByJm2g',
#    'https://www.youtube.com/channel/UC_vMxkZeIEQXK8snsBCOlpw',
#    'https://www.youtube.com/channel/UCoPGIiWGsVIEGo8DffljpQA',
#    'https://www.youtube.com/channel/UCqwUrj10mAEsqezcItqvwEw',
#    'https://www.youtube.com/channel/UCuhkaTaUtz9ba_BYWjA_sUA']},
#  {'cluster_name': 'kold, animals, kolder, tides, shifting',
#   'links': ['https://www.youtube.com/channel/UCDRZWhedLhwllnac-RBxvyw',
#    'https://www.youtube.com/channel/UCMkVkFlYZCqkmLLXwPXAFqw',
#    'https://www.youtube.com/channel/UC_tXKhJlqZrgr_qdhEKmrDQ',
#    'https://www.youtube.com/channel/UCen0ko30XIeN5IARS3E_Znw']},
#  {'cluster_name': 'mantra, bhajan, shiva, durga, sai',
#   'links': ['https://www.youtube.com/channel/UC1DdFzHNvp2Vv86vyi46MNA',
#    'https://www.youtube.com/channel/UC9EoLvDSRjGx8FWhI6tJsxA',
#    'https://www.youtube.com/channel/UCKIZijugeVt92lbP5YTwMiA',
#    'https://www.youtube.com/channel/UCKyZ2QnNEtQlN13FvOcSGDw',
#    'https://www.youtube.com/channel/UCPzCBQC5-hWRmK5DbLSysdw',
#    'https://www.youtube.com/channel/UCRJGywIBeuhtRKeIEj9NGHw',
#    'https://www.youtube.com/channel/UCSc6wkH9Jp9zzegKoBViXoQ',
#    'https://www.youtube.com/channel/UCT8M_hDfTRjUbs8hwahZyBA',
#    'https://www.youtube.com/channel/UCV0DVncZjaudmyfZRrLZXVg',
#    'https://www.youtube.com/channel/UCZJSg5r9IBgknv0VQAVoETg',
#    'https://www.youtube.com/channel/UCaF3MVnBYNnjAKF16k3mUjw',
#    'https://www.youtube.com/channel/UCeVefxaWBcjrvHxcc5EfIqw']},
#  {'cluster_name': 'music, guitar, berklee, ukulele, flute',
#   'links': ['https://www.youtube.com/channel/UCOR-iqlcedb8VMnax37m3MQ',
#    'https://www.youtube.com/channel/UCQRELbX0H5FCokIFxOAsHFA',
#    'https://www.youtube.com/channel/UCS3dfr0uOIC6OP-rSECVPMA',
#    'https://www.youtube.com/channel/UCVv7h9KKcQ5B6KFVHOhZl4Q',
#    'https://www.youtube.com/channel/UCXGiCLn-Xh9VwDT8h06rOIA',
#    'https://www.youtube.com/channel/UCa2OR2nl26Ht0Gg_IkCd7DQ',
#    'https://www.youtube.com/channel/UCa9852OG1OJwMYAi7Arb2ag',
#    'https://www.youtube.com/channel/UCayzTot0bZq1U5NUNhvNDdQ',
#    'https://www.youtube.com/channel/UCgkEdNiebvq-x8TMkZbqVgg',
#    'https://www.youtube.com/channel/UCpDJl2EmP7Oh90Vylx0dZtA',
#    'https://www.youtube.com/channel/UCtdQmE-3ny-M3twGKmOrTcg']},
#  {'cluster_name': 'peterson, jordan, personality, psychology, clips',
#   'links': ['https://www.youtube.com/channel/UC3zTcrgezTG_bHRA8fmlmmA',
#    'https://www.youtube.com/channel/UC6MXE0Px3m1aI4vI0pLWzQg',
#    'https://www.youtube.com/channel/UCFh3dBRQToGvu8bjr-CdV4Q',
#    'https://www.youtube.com/channel/UCFkDAsyfvgxqNyue4F4HHww',
#    'https://www.youtube.com/channel/UCL_f53ZEJxp8TtlOkHwMV9Q',
#    'https://www.youtube.com/channel/UCodkb-qBktJI5NrUsPYpf7g']},
#  {'cluster_name': 'prank, shorts, onlyjayus, iphone, vrchat',
#   'links': ['https://www.youtube.com/channel/UC0MYNOsIrz6jmXfIMERyRHQ',
#    'https://www.youtube.com/channel/UC4wOd-OGys-RKbv9FYFGRvA',
#    'https://www.youtube.com/channel/UCP8dEm4e63fY8rG-cQXgo7A',
#    'https://www.youtube.com/channel/UCSrnmu3W6YXWU_85DKT5arg',
#    'https://www.youtube.com/channel/UCUMVRo_qY2RKrEweB9rCv6g',
#    'https://www.youtube.com/channel/UCUxc0iEpV8wZV4WLOui0RwQ',
#    'https://www.youtube.com/channel/UCV5mGxp-rtsGDAedDYnp7hA',
#    'https://www.youtube.com/channel/UCV8Qe8z3RDLiAV7E0WP7-Fg',
#    'https://www.youtube.com/channel/UCXUrDDdmQHni2UTSNyIh4ag',
#    'https://www.youtube.com/channel/UCdC0An4ZPNr_YiFiYoVbwaw',
#    'https://www.youtube.com/channel/UCr8Xk8otTXckBw2rXEQXMuA',
#    'https://www.youtube.com/channel/UCsTcErHg8oDvUnTzoqsYeNw',
#    'https://www.youtube.com/channel/UCuDz-AQO2KuXzjtxoycrnJg',
#    'https://www.youtube.com/channel/UCvkdpLN1agXoiRWEWTtXqjw']},
#  {'cluster_name': 'product, management, marketing, sales, carey',
#   'links': ['https://www.youtube.com/channel/UC2qUDKqTsz00csykCYgdLuA',
#    'https://www.youtube.com/channel/UCE2ga5Jn6DbFv58_DTKs0XA',
#    'https://www.youtube.com/channel/UCKL_fwNBR9b4M5Bgyad3KUw',
#    'https://www.youtube.com/channel/UCWtWeBSsUpYkLnGGyHDSiOQ',
#    'https://www.youtube.com/channel/UCkIkqvPmO5UP6Q5so4hYFBA']},
#  {'cluster_name': 'python, google, dash, software, programming',
#   'links': ['https://www.youtube.com/channel/UCBGOUQHNNtNGcGzVq5rIXjw',
#    'https://www.youtube.com/channel/UCCezIgC97PvUuR4_gbFUs5g',
#    'https://www.youtube.com/channel/UCLz7LG4YVi7_iyk4yOARcxA',
#    'https://www.youtube.com/channel/UCRPMAqdtSgd0Ipeef7iFsKw',
#    'https://www.youtube.com/channel/UCWX0cUR2rZcqKei1Vstww-A',
#    'https://www.youtube.com/channel/UCY6N8zZhs2V7gNTUxPuKWoQ',
#    'https://www.youtube.com/channel/UCfeMEuhdUtxtaUMNSvxq_Xg',
#    'https://www.youtube.com/channel/UCqBFsuAz41sqWcFjZkqmJqQ',
#    'https://www.youtube.com/channel/UCtyYTpFBzWdoSFx2Gl2VNbQ']},
#  {'cluster_name': 'quantum, holes, flammy, integral, interpretation',
#   'links': ['https://www.youtube.com/channel/UCFe6jenM1Bc54qtBsIJGRZQ',
#    'https://www.youtube.com/channel/UCFk__1iexL3T5gvGcMpeHNA',
#    'https://www.youtube.com/channel/UCO3xnVTHzB7l-nc8mABUJIQ',
#    'https://www.youtube.com/channel/UCtAIs1VCQrymlAnw3mGonhw']},
#  {'cluster_name': 'sbi, rachana, market, ca, card',
#   'links': ['https://www.youtube.com/channel/UC44KdlZ8z3R3bgqUwMch8UQ',
#    'https://www.youtube.com/channel/UCWHCXSKASuSzao_pplQ7SPw',
#    'https://www.youtube.com/channel/UCe3qdG0A_gr-sEdat5y2twQ',
#    'https://www.youtube.com/channel/UCkoF2InqbcpBEdHC7KlnaLw']},
#  {'cluster_name': 'shooting, gun, glock, review, ak',
#   'links': ['https://www.youtube.com/channel/UCG1_A0jPBGZUpRW7XkaaBkg',
#    'https://www.youtube.com/channel/UCIOGCEG14rj9GpIFhszkWoQ',
#    'https://www.youtube.com/channel/UCIugi05X4JKUQz3WPD-YKog',
#    'https://www.youtube.com/channel/UCTrSsPMmZavLbc3Ex7VhjDg',
#    'https://www.youtube.com/channel/UCd3rCGu_2R_5LN6IcCBHIQA',
#    'https://www.youtube.com/channel/UCsrKsXEAqCbZyVrCibkgpwQ',
#    'https://www.youtube.com/channel/UCvB3solmhqtgDeLpD-yTtfg']},
#  {'cluster_name': 'songs, song, music, cover, mishra',
#   'links': ['https://www.youtube.com/channel/UC101sGN0S49Ig2eq6Wd6kRA',
#    'https://www.youtube.com/channel/UC7A0P8INcRIbhgFQ1v46Uyg',
#    'https://www.youtube.com/channel/UC88xLZCCJdPg_pXp5D8AgiQ',
#    'https://www.youtube.com/channel/UC8JB-8J7XUfYeIJKvEA1DkA',
#    'https://www.youtube.com/channel/UCK_ungzYZjsoeuCvzv8RTog',
#    'https://www.youtube.com/channel/UCM1VesJtJ9vTXcMLLr_FfdQ',
#    'https://www.youtube.com/channel/UCOaiVpNH05aP0hom0SovBYA',
#    'https://www.youtube.com/channel/UCUwSeY7lUdZSP0vuflq1oPA',
#    'https://www.youtube.com/channel/UCUz48nBLEvfE-2rtjuHLt4A',
#    'https://www.youtube.com/channel/UCWXYdNyGX01rnTB-tQci8JQ',
#    'https://www.youtube.com/channel/UCdnPPbjGZiX7Dw56YDYVDsg',
#    'https://www.youtube.com/channel/UCh7kXF6HwKgX--ByiWfN7-w',
#    'https://www.youtube.com/channel/UCi-HnKxk5lAE6Uvj5-dHn1g',
#    'https://www.youtube.com/channel/UCjDPr0Df-r6mtqwEHvHY_bA',
#    'https://www.youtube.com/channel/UCjbJGtcD7PGwcm8UUUBzGaQ',
#    'https://www.youtube.com/channel/UClNLaSXR1o0VcnqZl05gIQQ',
#    'https://www.youtube.com/channel/UCn4rEMqKtwBQ6-oEwbd4PcA',
#    'https://www.youtube.com/channel/UCnU9c8lf6Cvfz8VkD4fxbVQ',
#    'https://www.youtube.com/channel/UCnimG5HX-XSbso0bxpBFH2w',
#    'https://www.youtube.com/channel/UCp8v5KixDUzI8z8crVCXj-g',
#    'https://www.youtube.com/channel/UCq-Fj5jknLsUf-MWSy4_brA',
#    'https://www.youtube.com/channel/UCx4xrSYSfLATFO9fmPZxeNQ',
#    'https://www.youtube.com/channel/UCy436qLXlyLqddExVC64auw',
#    'https://www.youtube.com/channel/UCy5mW8fB24ITiiC0etjLI6w']},
#  {'cluster_name': 'startup, design, entrepreneurship, startups, sales',
#   'links': ['https://www.youtube.com/channel/UC-b3c7kxa5vU-bnmaROgvog',
#    'https://www.youtube.com/channel/UC9cn0TuPq4dnbTY-CBsm8XA',
#    'https://www.youtube.com/channel/UCQzHhoWHxmRS07TFx2D7lpQ',
#    'https://www.youtube.com/channel/UCcefcZRL2oaA_uBNeo5UOWg',
#    'https://www.youtube.com/channel/UCtiqGX-_f8kA0MZkQ4yPJ5g',
#    'https://www.youtube.com/channel/UCvBGFeXbBrq3W9_0oNLJREQ',
#    'https://www.youtube.com/channel/UCwB3HiWejAkml1UZ0Qo2bFg']},
#  {'cluster_name': 'subliminal, affirmations, meditation, mind, hypnosis',
#   'links': ['https://www.youtube.com/channel/UC-UYJe8O87Y9Qo3XJQRDljg',
#    'https://www.youtube.com/channel/UCNLvvsB75P4VMubocS3dlmg',
#    'https://www.youtube.com/channel/UCUh6k9ReBf1GTLCHRHDI2pw',
#    'https://www.youtube.com/channel/UCgnTNj3QFz7gJ18lMGmf4Ow',
#    'https://www.youtube.com/channel/UCqTU2-sZlJZppgwb_Z5LXhQ',
#    'https://www.youtube.com/channel/UCqWB6EseWbMKnzunyewBDqg',
#    'https://www.youtube.com/channel/UCr4mZxG-wPWMUn5aLl8q4-Q',
#    'https://www.youtube.com/channel/UCrIOuPmqRLVmHKNGldGf2Kw',
#    'https://www.youtube.com/channel/UCvAE7ZA69WIT8uJNnNXilIQ']},
#  {'cluster_name': 'ukraine, russia, news, tldr, chomsky',
#   'links': ['https://www.youtube.com/channel/UC-uhvujip5deVcEtLxnW8qg',
#    'https://www.youtube.com/channel/UC4Yk3q9vmANVVMXOST89kxQ',
#    'https://www.youtube.com/channel/UCGx3AJSkWe9mLJ1m9PsFJTA',
#    'https://www.youtube.com/channel/UCHuLYgw4dGbC2BuZQqPWV1g',
#    'https://www.youtube.com/channel/UCT3v6vL2H5HK4loLMc8pmCw',
#    'https://www.youtube.com/channel/UC_gUM8rL-Lrg6O3adPW9K1g',
#    'https://www.youtube.com/channel/UCfdNM3NAhaBOXCafH7krzrA',
#    'https://www.youtube.com/channel/UCwqusr8YDwM-3mEYTDeJHzw']},
#  {'cluster_name': 'usa, abroad, dallas, student, visa',
#   'links': ['https://www.youtube.com/channel/UC-cDK8t9TBFWEnCyoTYIR-Q',
#    'https://www.youtube.com/channel/UCDLoaI_zOwy_vCPnie9fCXQ',
#    'https://www.youtube.com/channel/UCES9tUazzGfrZlruMzue5DA',
#    'https://www.youtube.com/channel/UCGtklTE2ih72CgyvNwEO_iw',
#    'https://www.youtube.com/channel/UCQEkgUtOXa-1PSzg4fC_H8g',
#    'https://www.youtube.com/channel/UCbzwtpaN0stcTVb8aCbLq0A',
#    'https://www.youtube.com/channel/UChYs-_zjKRYhdMddjx-NPLw',
#    'https://www.youtube.com/channel/UCptc7b3jk_PtbpLLeZojRZA',
#    'https://www.youtube.com/channel/UCydVjjfO74Vr7Scecn1sNAg']},
#  {'cluster_name': 'vending, stradman, cars, collection, machine',
#   'links': ['https://www.youtube.com/channel/UC21Kozr_K0yDM-VjoihG9Aw',
#    'https://www.youtube.com/channel/UCmsAwNJKAGI2ibq--B-unKw',
#    'https://www.youtube.com/channel/UCvbJKkmSauhJz0FRFd6nuOQ']},
#  {'cluster_name': 'vice, documentary, news, history, world',
#   'links': ['https://www.youtube.com/channel/UC6n8I1UDTKP1IWjQMg6_TwA',
#    'https://www.youtube.com/channel/UC88lvyJe7aHZmcvzvubDFRg',
#    'https://www.youtube.com/channel/UC8Su5vZCXWRag13H53zWVwA',
#    'https://www.youtube.com/channel/UC9RM-iSvTu1uPJb8X5yp3EQ',
#    'https://www.youtube.com/channel/UCK7tptUDHh-RYDsdxO1-5QQ',
#    'https://www.youtube.com/channel/UCP5tjEmvPItGyLhmjdwP7Ww',
#    'https://www.youtube.com/channel/UCZaT_X_mc0BI-djXOlfhqWQ',
#    'https://www.youtube.com/channel/UCb7xZQi7F3RW7BNtR57cNnA',
#    'https://www.youtube.com/channel/UCjn8bDuukMsi0tAzSSVTyNQ',
#    'https://www.youtube.com/channel/UCmGSJVG3mCRXVOP4yZrU1Dw',
#    'https://www.youtube.com/channel/UCn4sPeUomNGIr26bElVdDYg',
#    'https://www.youtube.com/channel/UCn8zNIfYAQNdrFRrr8oibKw',
#    'https://www.youtube.com/channel/UCpVm7bg6pXKo1Pr6k5kxG9A']},
#  {'cluster_name': 'workout, fitness, healthy, calisthenics, dr',
#   'links': ['https://www.youtube.com/channel/UC3Rny1I5JXgZYvWUzWMMU4Q',
#    'https://www.youtube.com/channel/UC4GTYUQEZSQ-28KNX7I0ngw',
#    'https://www.youtube.com/channel/UC8-9mdGBP5dtxEKJM2E9bHA',
#    'https://www.youtube.com/channel/UC8lu7lA1CyFQ9EavhThSsdQ',
#    'https://www.youtube.com/channel/UCAtYISjPM8p1-8ot1vf9kPA',
#    'https://www.youtube.com/channel/UCE8wCVw_ZfRw-D6RJ5EXWbw',
#    'https://www.youtube.com/channel/UCHCZnC9akNA9pBP7aJGNKdg',
#    'https://www.youtube.com/channel/UCKcWSiffY8MpZ3NKav8LeRA',
#    'https://www.youtube.com/channel/UCeJFgNahi--FKs0oJyeRDEw',
#    'https://www.youtube.com/channel/UCiP6wD_tYlYLYh3agzbByWQ',
#    'https://www.youtube.com/channel/UClngPjkNmITx8dkTFV6P0sA',
#    'https://www.youtube.com/channel/UCxkqZw7BI-Ta9778vnZnDMA']}]

# %%
df.to_dict('records')
# Out:
# [{'channel_id': 'UC-91UA-Xy2Cvb98deRXuggA',
#   'channel_url': 'https://www.youtube.com/channel/UC-91UA-Xy2Cvb98deRXuggA',
#   'cluster': 19,
#   'cluster_name': 'job, shorts, career, work, iit'},
#  {'channel_id': 'UC-UYJe8O87Y9Qo3XJQRDljg',
#   'channel_url': 'https://www.youtube.com/channel/UC-UYJe8O87Y9Qo3XJQRDljg',
#   'cluster': 26,
#   'cluster_name': 'subliminal, affirmations, meditation, mind, hypnosis'},
#  {'channel_id': 'UC-b3c7kxa5vU-bnmaROgvog',
#   'channel_url': 'https://www.youtube.com/channel/UC-b3c7kxa5vU-bnmaROgvog',
#   'cluster': 28,
#   'cluster_name': 'startup, design, entrepreneurship, startups, sales'},
#  {'channel_id': 'UC-cDK8t9TBFWEnCyoTYIR-Q',
#   'channel_url': 'https://www.youtube.com/channel/UC-cDK8t9TBFWEnCyoTYIR-Q',
#   'cluster': 20,
#   'cluster_name': 'usa, abroad, dallas, student, visa'},
#  {'channel_id': 'UC-dmJ79518WlKMbsu50eMTQ',
#   'channel_url': 'https://www.youtube.com/channel/UC-dmJ79518WlKMbsu50eMTQ',
#   'cluster': 29,
#   'cluster_name': 'healing, attraction, law, shivani, pranic'},
#  {'channel_id': 'UC-fn57_xqMv-PaMmpm-ZspQ',
#   'channel_url': 'https://www.youtube.com/channel/UC-fn57_xqMv-PaMmpm-ZspQ',
#   'cluster': 23,
#   'cluster_name': 'echosmith, shuba, ed, music, sheeran'},
#  {'channel_id': 'UC-uhvujip5deVcEtLxnW8qg',
#   'channel_url': 'https://www.youtube.com/channel/UC-uhvujip5deVcEtLxnW8qg',
#   'cluster': 21,
#   'cluster_name': 'ukraine, russia, news, tldr, chomsky'},
#  {'channel_id': 'UC-vGXUq70B4p6BD-z-711hQ',
#   'channel_url': 'https://www.youtube.com/channel/UC-vGXUq70B4p6BD-z-711hQ',
#   'cluster': 30,
#   'cluster_name': 'kannada, comedy, funny, vines, prank'},
#  {'channel_id': 'UC0C-w0YjGpqDXGB8IHb662A',
#   'channel_url': 'https://www.youtube.com/channel/UC0C-w0YjGpqDXGB8IHb662A',
#   'cluster': 23,
#   'cluster_name': 'echosmith, shuba, ed, music, sheeran'},
#  {'channel_id': 'UC0DM_mHV2u6dj8ig51GkQwg',
#   'channel_url': 'https://www.youtube.com/channel/UC0DM_mHV2u6dj8ig51GkQwg',
#   'cluster': 15,
#   'cluster_name': 'documentary, telegraph, bbc, tv, news'},
#  {'channel_id': 'UC0L1suV8pVgO4pCAIBNGx5w',
#   'channel_url': 'https://www.youtube.com/channel/UC0L1suV8pVgO4pCAIBNGx5w',
#   'cluster': 15,
#   'cluster_name': 'documentary, telegraph, bbc, tv, news'},
#  {'channel_id': 'UC0MYNOsIrz6jmXfIMERyRHQ',
#   'channel_url': 'https://www.youtube.com/channel/UC0MYNOsIrz6jmXfIMERyRHQ',
#   'cluster': 11,
#   'cluster_name': 'prank, shorts, onlyjayus, iphone, vrchat'},
#  {'channel_id': 'UC0patpmwYbhcEUap0bTX3JQ',
#   'channel_url': 'https://www.youtube.com/channel/UC0patpmwYbhcEUap0bTX3JQ',
#   'cluster': 18,
#   'cluster_name': 'data, science, learning, google, tensorflow'},
#  {'channel_id': 'UC0rE2qq81of4fojo-KhO5rg',
#   'channel_url': 'https://www.youtube.com/channel/UC0rE2qq81of4fojo-KhO5rg',
#   'cluster': 30,
#   'cluster_name': 'kannada, comedy, funny, vines, prank'},
#  {'channel_id': 'UC0rqucBdTuFTjJiefW5t-IQ',
#   'channel_url': 'https://www.youtube.com/channel/UC0rqucBdTuFTjJiefW5t-IQ',
#   'cluster': 18,
#   'cluster_name': 'data, science, learning, google, tensorflow'},
#  {'channel_id': 'UC101sGN0S49Ig2eq6Wd6kRA',
#   'channel_url': 'https://www.youtube.com/channel/UC101sGN0S49Ig2eq6Wd6kRA',
#   'cluster': 2,
#   'cluster_name': 'songs, song, music, cover, mishra'},
#  {'channel_id': 'UC1DdFzHNvp2Vv86vyi46MNA',
#   'channel_url': 'https://www.youtube.com/channel/UC1DdFzHNvp2Vv86vyi46MNA',
#   'cluster': 5,
#   'cluster_name': 'mantra, bhajan, shiva, durga, sai'},
#  {'channel_id': 'UC1S4Jeodbr5EbsCOIgBWJPQ',
#   'channel_url': 'https://www.youtube.com/channel/UC1S4Jeodbr5EbsCOIgBWJPQ',
#   'cluster': 16,
#   'cluster_name': 'gre, toefl, ielts, test, vocabulary'},
#  {'channel_id': 'UC21Kozr_K0yDM-VjoihG9Aw',
#   'channel_url': 'https://www.youtube.com/channel/UC21Kozr_K0yDM-VjoihG9Aw',
#   'cluster': 12,
#   'cluster_name': 'vending, stradman, cars, collection, machine'},
#  {'channel_id': 'UC22B9hVNit3v7nOhxsK6wVQ',
#   'channel_url': 'https://www.youtube.com/channel/UC22B9hVNit3v7nOhxsK6wVQ',
#   'cluster': 29,
#   'cluster_name': 'healing, attraction, law, shivani, pranic'},
#  {'channel_id': 'UC28Nsu2CmbXRD1eGqMVcpYg',
#   'channel_url': 'https://www.youtube.com/channel/UC28Nsu2CmbXRD1eGqMVcpYg',
#   'cluster': 19,
#   'cluster_name': 'job, shorts, career, work, iit'},
#  {'channel_id': 'UC2QhYM2_8ONHsWxkUiS7shQ',
#   'channel_url': 'https://www.youtube.com/channel/UC2QhYM2_8ONHsWxkUiS7shQ',
#   'cluster': 19,
#   'cluster_name': 'job, shorts, career, work, iit'},
#  {'channel_id': 'UC2qUDKqTsz00csykCYgdLuA',
#   'channel_url': 'https://www.youtube.com/channel/UC2qUDKqTsz00csykCYgdLuA',
#   'cluster': 32,
#   'cluster_name': 'product, management, marketing, sales, carey'},
#  {'channel_id': 'UC3Rny1I5JXgZYvWUzWMMU4Q',
#   'channel_url': 'https://www.youtube.com/channel/UC3Rny1I5JXgZYvWUzWMMU4Q',
#   'cluster': 7,
#   'cluster_name': 'workout, fitness, healthy, calisthenics, dr'},
#  {'channel_id': 'UC3Vuq4Q1bKFtAiKYlwRv3oA',
#   'channel_url': 'https://www.youtube.com/channel/UC3Vuq4Q1bKFtAiKYlwRv3oA',
#   'cluster': 9,
#   'cluster_name': 'dubai, amish, dignity, nas, zaidalit'},
#  {'channel_id': 'UC3f6OYvhpV-pmTYgikEbF1g',
#   'channel_url': 'https://www.youtube.com/channel/UC3f6OYvhpV-pmTYgikEbF1g',
#   'cluster': 19,
#   'cluster_name': 'job, shorts, career, work, iit'},
#  {'channel_id': 'UC3zTcrgezTG_bHRA8fmlmmA',
#   'channel_url': 'https://www.youtube.com/channel/UC3zTcrgezTG_bHRA8fmlmmA',
#   'cluster': 10,
#   'cluster_name': 'peterson, jordan, personality, psychology, clips'},
#  {'channel_id': 'UC415bOPUcGSamy543abLmRA',
#   'channel_url': 'https://www.youtube.com/channel/UC415bOPUcGSamy543abLmRA',
#   'cluster': 0,
#   'cluster_name': 'english, study, big, harvard, brown'},
#  {'channel_id': 'UC44KdlZ8z3R3bgqUwMch8UQ',
#   'channel_url': 'https://www.youtube.com/channel/UC44KdlZ8z3R3bgqUwMch8UQ',
#   'cluster': 24,
#   'cluster_name': 'sbi, rachana, market, ca, card'},
#  {'channel_id': 'UC4GTYUQEZSQ-28KNX7I0ngw',
#   'channel_url': 'https://www.youtube.com/channel/UC4GTYUQEZSQ-28KNX7I0ngw',
#   'cluster': 7,
#   'cluster_name': 'workout, fitness, healthy, calisthenics, dr'},
#  {'channel_id': 'UC4Yk3q9vmANVVMXOST89kxQ',
#   'channel_url': 'https://www.youtube.com/channel/UC4Yk3q9vmANVVMXOST89kxQ',
#   'cluster': 21,
#   'cluster_name': 'ukraine, russia, news, tldr, chomsky'},
#  {'channel_id': 'UC4aTcVTewbHtLeV8eK3enwA',
#   'channel_url': 'https://www.youtube.com/channel/UC4aTcVTewbHtLeV8eK3enwA',
#   'cluster': 30,
#   'cluster_name': 'kannada, comedy, funny, vines, prank'},
#  {'channel_id': 'UC4qJ0wpfqPY4PnaNZAuRVuA',
#   'channel_url': 'https://www.youtube.com/channel/UC4qJ0wpfqPY4PnaNZAuRVuA',
#   'cluster': 19,
#   'cluster_name': 'job, shorts, career, work, iit'},
#  {'channel_id': 'UC4wOd-OGys-RKbv9FYFGRvA',
#   'channel_url': 'https://www.youtube.com/channel/UC4wOd-OGys-RKbv9FYFGRvA',
#   'cluster': 11,
#   'cluster_name': 'prank, shorts, onlyjayus, iphone, vrchat'},
#  {'channel_id': 'UC59KhIPOR0Jj653dC4laEJw',
#   'channel_url': 'https://www.youtube.com/channel/UC59KhIPOR0Jj653dC4laEJw',
#   'cluster': 14,
#   'cluster_name': 'comedy, trevor, noah, funny, netflix'},
#  {'channel_id': 'UC5H_lY2y5X3zhjy5KTez-vQ',
#   'channel_url': 'https://www.youtube.com/channel/UC5H_lY2y5X3zhjy5KTez-vQ',
#   'cluster': 8,
#   'cluster_name': 'india, sadhguru, google, canada, indian'},
#  {'channel_id': 'UC5YEoYuciHpO_0s1Mpz8_JA',
#   'channel_url': 'https://www.youtube.com/channel/UC5YEoYuciHpO_0s1Mpz8_JA',
#   'cluster': 23,
#   'cluster_name': 'echosmith, shuba, ed, music, sheeran'},
#  {'channel_id': 'UC6-URUKHVmFWSt_KdRsX8UA',
#   'channel_url': 'https://www.youtube.com/channel/UC6-URUKHVmFWSt_KdRsX8UA',
#   'cluster': 3,
#   'cluster_name': 'bloomberg, news, bitcoin, economy, economics'},
#  {'channel_id': 'UC65BYtqlRNjR93D5UxGVfXw',
#   'channel_url': 'https://www.youtube.com/channel/UC65BYtqlRNjR93D5UxGVfXw',
#   'cluster': 0,
#   'cluster_name': 'english, study, big, harvard, brown'},
#  {'channel_id': 'UC6MXE0Px3m1aI4vI0pLWzQg',
#   'channel_url': 'https://www.youtube.com/channel/UC6MXE0Px3m1aI4vI0pLWzQg',
#   'cluster': 10,
#   'cluster_name': 'peterson, jordan, personality, psychology, clips'},
#  {'channel_id': 'UC6n8I1UDTKP1IWjQMg6_TwA',
#   'channel_url': 'https://www.youtube.com/channel/UC6n8I1UDTKP1IWjQMg6_TwA',
#   'cluster': 13,
#   'cluster_name': 'vice, documentary, news, history, world'},
#  {'channel_id': 'UC79RWgVZMQa2VOABDPPFvtA',
#   'channel_url': 'https://www.youtube.com/channel/UC79RWgVZMQa2VOABDPPFvtA',
#   'cluster': 9,
#   'cluster_name': 'dubai, amish, dignity, nas, zaidalit'},
#  {'channel_id': 'UC7A0P8INcRIbhgFQ1v46Uyg',
#   'channel_url': 'https://www.youtube.com/channel/UC7A0P8INcRIbhgFQ1v46Uyg',
#   'cluster': 2,
#   'cluster_name': 'songs, song, music, cover, mishra'},
#  {'channel_id': 'UC7C-v-OEqBE641x6SsveaGA',
#   'channel_url': 'https://www.youtube.com/channel/UC7C-v-OEqBE641x6SsveaGA',
#   'cluster': 30,
#   'cluster_name': 'kannada, comedy, funny, vines, prank'},
#  {'channel_id': 'UC7bCIt-Dk1ZAQIMcdoNmhIQ',
#   'channel_url': 'https://www.youtube.com/channel/UC7bCIt-Dk1ZAQIMcdoNmhIQ',
#   'cluster': 8,
#   'cluster_name': 'india, sadhguru, google, canada, indian'},
#  {'channel_id': 'UC7eHZXheF8nVOfwB2PEslMw',
#   'channel_url': 'https://www.youtube.com/channel/UC7eHZXheF8nVOfwB2PEslMw',
#   'cluster': 30,
#   'cluster_name': 'kannada, comedy, funny, vines, prank'},
#  {'channel_id': 'UC7kbAF7LWIk1pPftd-9ziMw',
#   'channel_url': 'https://www.youtube.com/channel/UC7kbAF7LWIk1pPftd-9ziMw',
#   'cluster': 31,
#   'cluster_name': 'homeopathic, medicine, homeopathy, rsverma, dr'},
#  {'channel_id': 'UC7t4llTRPqj6FeZiDR1Ya_g',
#   'channel_url': 'https://www.youtube.com/channel/UC7t4llTRPqj6FeZiDR1Ya_g',
#   'cluster': 8,
#   'cluster_name': 'india, sadhguru, google, canada, indian'},
#  {'channel_id': 'UC8-9mdGBP5dtxEKJM2E9bHA',
#   'channel_url': 'https://www.youtube.com/channel/UC8-9mdGBP5dtxEKJM2E9bHA',
#   'cluster': 7,
#   'cluster_name': 'workout, fitness, healthy, calisthenics, dr'},
#  {'channel_id': 'UC8-Th83bH_thdKZDJCrn88g',
#   'channel_url': 'https://www.youtube.com/channel/UC8-Th83bH_thdKZDJCrn88g',
#   'cluster': 14,
#   'cluster_name': 'comedy, trevor, noah, funny, netflix'},
#  {'channel_id': 'UC88lvyJe7aHZmcvzvubDFRg',
#   'channel_url': 'https://www.youtube.com/channel/UC88lvyJe7aHZmcvzvubDFRg',
#   'cluster': 13,
#   'cluster_name': 'vice, documentary, news, history, world'},
#  {'channel_id': 'UC88xLZCCJdPg_pXp5D8AgiQ',
#   'channel_url': 'https://www.youtube.com/channel/UC88xLZCCJdPg_pXp5D8AgiQ',
#   'cluster': 2,
#   'cluster_name': 'songs, song, music, cover, mishra'},
#  {'channel_id': 'UC8JB-8J7XUfYeIJKvEA1DkA',
#   'channel_url': 'https://www.youtube.com/channel/UC8JB-8J7XUfYeIJKvEA1DkA',
#   'cluster': 2,
#   'cluster_name': 'songs, song, music, cover, mishra'},
#  {'channel_id': 'UC8Su5vZCXWRag13H53zWVwA',
#   'channel_url': 'https://www.youtube.com/channel/UC8Su5vZCXWRag13H53zWVwA',
#   'cluster': 13,
#   'cluster_name': 'vice, documentary, news, history, world'},
#  {'channel_id': 'UC8XKyvQ5Ne_bvYbgv8LaIeg',
#   'channel_url': 'https://www.youtube.com/channel/UC8XKyvQ5Ne_bvYbgv8LaIeg',
#   'cluster': 19,
#   'cluster_name': 'job, shorts, career, work, iit'},
#  {'channel_id': 'UC8bTQzxgvKkXDAaWkeuUlkg',
#   'channel_url': 'https://www.youtube.com/channel/UC8bTQzxgvKkXDAaWkeuUlkg',
#   'cluster': 14,
#   'cluster_name': 'comedy, trevor, noah, funny, netflix'},
#  {'channel_id': 'UC8lu7lA1CyFQ9EavhThSsdQ',
#   'channel_url': 'https://www.youtube.com/channel/UC8lu7lA1CyFQ9EavhThSsdQ',
#   'cluster': 7,
#   'cluster_name': 'workout, fitness, healthy, calisthenics, dr'},
#  {'channel_id': 'UC8ofcOdHNINiPrBA9D59Vaw',
#   'channel_url': 'https://www.youtube.com/channel/UC8ofcOdHNINiPrBA9D59Vaw',
#   'cluster': 18,
#   'cluster_name': 'data, science, learning, google, tensorflow'},
#  {'channel_id': 'UC9EoLvDSRjGx8FWhI6tJsxA',
#   'channel_url': 'https://www.youtube.com/channel/UC9EoLvDSRjGx8FWhI6tJsxA',
#   'cluster': 5,
#   'cluster_name': 'mantra, bhajan, shiva, durga, sai'},
#  {'channel_id': 'UC9HGzFGt7BLmWDqooUbWGBg',
#   'channel_url': 'https://www.youtube.com/channel/UC9HGzFGt7BLmWDqooUbWGBg',
#   'cluster': 22,
#   'cluster_name': 'dating, gabblin, hussey, men, relationship'},
#  {'channel_id': 'UC9Jxk_mBmLLqOnm61r9EBuw',
#   'channel_url': 'https://www.youtube.com/channel/UC9Jxk_mBmLLqOnm61r9EBuw',
#   'cluster': 31,
#   'cluster_name': 'homeopathic, medicine, homeopathy, rsverma, dr'},
#  {'channel_id': 'UC9RM-iSvTu1uPJb8X5yp3EQ',
#   'channel_url': 'https://www.youtube.com/channel/UC9RM-iSvTu1uPJb8X5yp3EQ',
#   'cluster': 13,
#   'cluster_name': 'vice, documentary, news, history, world'},
#  {'channel_id': 'UC9cn0TuPq4dnbTY-CBsm8XA',
#   'channel_url': 'https://www.youtube.com/channel/UC9cn0TuPq4dnbTY-CBsm8XA',
#   'cluster': 28,
#   'cluster_name': 'startup, design, entrepreneurship, startups, sales'},
#  {'channel_id': 'UCAkYgW-5XG5uPyaO9PD_I5A',
#   'channel_url': 'https://www.youtube.com/channel/UCAkYgW-5XG5uPyaO9PD_I5A',
#   'cluster': 1,
#   'cluster_name': 'india, defence, indian, upsc, ias'},
#  {'channel_id': 'UCAmGmNMwqMNzIC-a6iOLagg',
#   'channel_url': 'https://www.youtube.com/channel/UCAmGmNMwqMNzIC-a6iOLagg',
#   'cluster': 30,
#   'cluster_name': 'kannada, comedy, funny, vines, prank'},
#  {'channel_id': 'UCAtYISjPM8p1-8ot1vf9kPA',
#   'channel_url': 'https://www.youtube.com/channel/UCAtYISjPM8p1-8ot1vf9kPA',
#   'cluster': 7,
#   'cluster_name': 'workout, fitness, healthy, calisthenics, dr'},
#  {'channel_id': 'UCBGOUQHNNtNGcGzVq5rIXjw',
#   'channel_url': 'https://www.youtube.com/channel/UCBGOUQHNNtNGcGzVq5rIXjw',
#   'cluster': 33,
#   'cluster_name': 'python, google, dash, software, programming'},
#  {'channel_id': 'UCB_oqEMvs9Xd7RKoG_8sCyA',
#   'channel_url': 'https://www.youtube.com/channel/UCB_oqEMvs9Xd7RKoG_8sCyA',
#   'cluster': 22,
#   'cluster_name': 'dating, gabblin, hussey, men, relationship'},
#  {'channel_id': 'UCBcG9TT58nA1w9Oo3Os3MMg',
#   'channel_url': 'https://www.youtube.com/channel/UCBcG9TT58nA1w9Oo3Os3MMg',
#   'cluster': 1,
#   'cluster_name': 'india, defence, indian, upsc, ias'},
#  {'channel_id': 'UCCQSX9nS2WTUrXib2vJN4hA',
#   'channel_url': 'https://www.youtube.com/channel/UCCQSX9nS2WTUrXib2vJN4hA',
#   'cluster': 8,
#   'cluster_name': 'india, sadhguru, google, canada, indian'},
#  {'channel_id': 'UCCezIgC97PvUuR4_gbFUs5g',
#   'channel_url': 'https://www.youtube.com/channel/UCCezIgC97PvUuR4_gbFUs5g',
#   'cluster': 33,
#   'cluster_name': 'python, google, dash, software, programming'},
#  {'channel_id': 'UCCgQaXjsJ6EdFPZeTFQoSyw',
#   'channel_url': 'https://www.youtube.com/channel/UCCgQaXjsJ6EdFPZeTFQoSyw',
#   'cluster': 8,
#   'cluster_name': 'india, sadhguru, google, canada, indian'},
#  {'channel_id': 'UCCj956IF62FbT7Gouszaj9w',
#   'channel_url': 'https://www.youtube.com/channel/UCCj956IF62FbT7Gouszaj9w',
#   'cluster': 15,
#   'cluster_name': 'documentary, telegraph, bbc, tv, news'},
#  {'channel_id': 'UCCoS6VGcKqYZCdaDHmv30Wg',
#   'channel_url': 'https://www.youtube.com/channel/UCCoS6VGcKqYZCdaDHmv30Wg',
#   'cluster': 31,
#   'cluster_name': 'homeopathic, medicine, homeopathy, rsverma, dr'},
#  {'channel_id': 'UCDLoaI_zOwy_vCPnie9fCXQ',
#   'channel_url': 'https://www.youtube.com/channel/UCDLoaI_zOwy_vCPnie9fCXQ',
#   'cluster': 20,
#   'cluster_name': 'usa, abroad, dallas, student, visa'},
#  {'channel_id': 'UCDRZWhedLhwllnac-RBxvyw',
#   'channel_url': 'https://www.youtube.com/channel/UCDRZWhedLhwllnac-RBxvyw',
#   'cluster': 25,
#   'cluster_name': 'kold, animals, kolder, tides, shifting'},
#  {'channel_id': 'UCE2ga5Jn6DbFv58_DTKs0XA',
#   'channel_url': 'https://www.youtube.com/channel/UCE2ga5Jn6DbFv58_DTKs0XA',
#   'cluster': 32,
#   'cluster_name': 'product, management, marketing, sales, carey'},
#  {'channel_id': 'UCE4yfbhDepYoRSAD-tBzJzg',
#   'channel_url': 'https://www.youtube.com/channel/UCE4yfbhDepYoRSAD-tBzJzg',
#   'cluster': 29,
#   'cluster_name': 'healing, attraction, law, shivani, pranic'},
#  {'channel_id': 'UCE8wCVw_ZfRw-D6RJ5EXWbw',
#   'channel_url': 'https://www.youtube.com/channel/UCE8wCVw_ZfRw-D6RJ5EXWbw',
#   'cluster': 7,
#   'cluster_name': 'workout, fitness, healthy, calisthenics, dr'},
#  {'channel_id': 'UCEIs9nkveW9WmYtsOcJBwTg',
#   'channel_url': 'https://www.youtube.com/channel/UCEIs9nkveW9WmYtsOcJBwTg',
#   'cluster': 9,
#   'cluster_name': 'dubai, amish, dignity, nas, zaidalit'},
#  {'channel_id': 'UCES9tUazzGfrZlruMzue5DA',
#   'channel_url': 'https://www.youtube.com/channel/UCES9tUazzGfrZlruMzue5DA',
#   'cluster': 20,
#   'cluster_name': 'usa, abroad, dallas, student, visa'},
#  {'channel_id': 'UCFPcOxYh3M5Es5KFkieW2Gg',
#   'channel_url': 'https://www.youtube.com/channel/UCFPcOxYh3M5Es5KFkieW2Gg',
#   'cluster': 0,
#   'cluster_name': 'english, study, big, harvard, brown'},
#  {'channel_id': 'UCFe6jenM1Bc54qtBsIJGRZQ',
#   'channel_url': 'https://www.youtube.com/channel/UCFe6jenM1Bc54qtBsIJGRZQ',
#   'cluster': 4,
#   'cluster_name': 'quantum, holes, flammy, integral, interpretation'},
#  {'channel_id': 'UCFh3dBRQToGvu8bjr-CdV4Q',
#   'channel_url': 'https://www.youtube.com/channel/UCFh3dBRQToGvu8bjr-CdV4Q',
#   'cluster': 10,
#   'cluster_name': 'peterson, jordan, personality, psychology, clips'},
#  {'channel_id': 'UCFkDAsyfvgxqNyue4F4HHww',
#   'channel_url': 'https://www.youtube.com/channel/UCFkDAsyfvgxqNyue4F4HHww',
#   'cluster': 10,
#   'cluster_name': 'peterson, jordan, personality, psychology, clips'},
#  {'channel_id': 'UCFk__1iexL3T5gvGcMpeHNA',
#   'channel_url': 'https://www.youtube.com/channel/UCFk__1iexL3T5gvGcMpeHNA',
#   'cluster': 4,
#   'cluster_name': 'quantum, holes, flammy, integral, interpretation'},
#  {'channel_id': 'UCFw1xwDebFOyCUKvHo2qRKQ',
#   'channel_url': 'https://www.youtube.com/channel/UCFw1xwDebFOyCUKvHo2qRKQ',
#   'cluster': 1,
#   'cluster_name': 'india, defence, indian, upsc, ias'},
#  {'channel_id': 'UCG1_A0jPBGZUpRW7XkaaBkg',
#   'channel_url': 'https://www.youtube.com/channel/UCG1_A0jPBGZUpRW7XkaaBkg',
#   'cluster': 17,
#   'cluster_name': 'shooting, gun, glock, review, ak'},
#  {'channel_id': 'UCG4aUmNL9W0I5hx6Zzp_3-A',
#   'channel_url': 'https://www.youtube.com/channel/UCG4aUmNL9W0I5hx6Zzp_3-A',
#   'cluster': 14,
#   'cluster_name': 'comedy, trevor, noah, funny, netflix'},
#  {'channel_id': 'UCGBoWe1mzCvbbqDNncmxm8A',
#   'channel_url': 'https://www.youtube.com/channel/UCGBoWe1mzCvbbqDNncmxm8A',
#   'cluster': 3,
#   'cluster_name': 'bloomberg, news, bitcoin, economy, economics'},
#  {'channel_id': 'UCGFNZxMqKLsqWERX_N2f08Q',
#   'channel_url': 'https://www.youtube.com/channel/UCGFNZxMqKLsqWERX_N2f08Q',
#   'cluster': 1,
#   'cluster_name': 'india, defence, indian, upsc, ias'},
#  {'channel_id': 'UCGnsRwFS8Xm13lMAeouzT9g',
#   'channel_url': 'https://www.youtube.com/channel/UCGnsRwFS8Xm13lMAeouzT9g',
#   'cluster': 23,
#   'cluster_name': 'echosmith, shuba, ed, music, sheeran'},
#  {'channel_id': 'UCGtklTE2ih72CgyvNwEO_iw',
#   'channel_url': 'https://www.youtube.com/channel/UCGtklTE2ih72CgyvNwEO_iw',
#   'cluster': 20,
#   'cluster_name': 'usa, abroad, dallas, student, visa'},
#  {'channel_id': 'UCGx3AJSkWe9mLJ1m9PsFJTA',
#   'channel_url': 'https://www.youtube.com/channel/UCGx3AJSkWe9mLJ1m9PsFJTA',
#   'cluster': 21,
#   'cluster_name': 'ukraine, russia, news, tldr, chomsky'},
#  {'channel_id': 'UCH5_L3ytGbBziX0CLuYdQ1Q',
#   'channel_url': 'https://www.youtube.com/channel/UCH5_L3ytGbBziX0CLuYdQ1Q',
#   'cluster': 19,
#   'cluster_name': 'job, shorts, career, work, iit'},
#  {'channel_id': 'UCHCZnC9akNA9pBP7aJGNKdg',
#   'channel_url': 'https://www.youtube.com/channel/UCHCZnC9akNA9pBP7aJGNKdg',
#   'cluster': 7,
#   'cluster_name': 'workout, fitness, healthy, calisthenics, dr'},
#  {'channel_id': 'UCHG1wZgWRqyLscd8xE3d6Ng',
#   'channel_url': 'https://www.youtube.com/channel/UCHG1wZgWRqyLscd8xE3d6Ng',
#   'cluster': 16,
#   'cluster_name': 'gre, toefl, ielts, test, vocabulary'},
#  {'channel_id': 'UCHQ6ijQ15cDKyqnD-aDf__g',
#   'channel_url': 'https://www.youtube.com/channel/UCHQ6ijQ15cDKyqnD-aDf__g',
#   'cluster': 30,
#   'cluster_name': 'kannada, comedy, funny, vines, prank'},
#  {'channel_id': 'UCHfYqxApaB6_DXCBuFSYG5w',
#   'channel_url': 'https://www.youtube.com/channel/UCHfYqxApaB6_DXCBuFSYG5w',
#   'cluster': 19,
#   'cluster_name': 'job, shorts, career, work, iit'},
#  {'channel_id': 'UCHuLYgw4dGbC2BuZQqPWV1g',
#   'channel_url': 'https://www.youtube.com/channel/UCHuLYgw4dGbC2BuZQqPWV1g',
#   'cluster': 21,
#   'cluster_name': 'ukraine, russia, news, tldr, chomsky'},
#  {'channel_id': 'UCI0xqzZrJdNlnsmzD_Fliiw',
#   'channel_url': 'https://www.youtube.com/channel/UCI0xqzZrJdNlnsmzD_Fliiw',
#   'cluster': 14,
#   'cluster_name': 'comedy, trevor, noah, funny, netflix'},
#  {'channel_id': 'UCI7-iazJE_CiuVw7_yEpinA',
#   'channel_url': 'https://www.youtube.com/channel/UCI7-iazJE_CiuVw7_yEpinA',
#   'cluster': 9,
#   'cluster_name': 'dubai, amish, dignity, nas, zaidalit'},
#  {'channel_id': 'UCIOGCEG14rj9GpIFhszkWoQ',
#   'channel_url': 'https://www.youtube.com/channel/UCIOGCEG14rj9GpIFhszkWoQ',
#   'cluster': 17,
#   'cluster_name': 'shooting, gun, glock, review, ak'},
#  {'channel_id': 'UCIRYBXDze5krPDzAEOxFGVA',
#   'channel_url': 'https://www.youtube.com/channel/UCIRYBXDze5krPDzAEOxFGVA',
#   'cluster': 15,
#   'cluster_name': 'documentary, telegraph, bbc, tv, news'},
#  {'channel_id': 'UCIRgg5VeGBSdnFy15eao8uQ',
#   'channel_url': 'https://www.youtube.com/channel/UCIRgg5VeGBSdnFy15eao8uQ',
#   'cluster': 30,
#   'cluster_name': 'kannada, comedy, funny, vines, prank'},
#  {'channel_id': 'UCIugi05X4JKUQz3WPD-YKog',
#   'channel_url': 'https://www.youtube.com/channel/UCIugi05X4JKUQz3WPD-YKog',
#   'cluster': 17,
#   'cluster_name': 'shooting, gun, glock, review, ak'},
#  {'channel_id': 'UCJ0uqCI0Vqr2Rrt1HseGirg',
#   'channel_url': 'https://www.youtube.com/channel/UCJ0uqCI0Vqr2Rrt1HseGirg',
#   'cluster': 14,
#   'cluster_name': 'comedy, trevor, noah, funny, netflix'},
#  {'channel_id': 'UCJKYubtV1bfbhS-SxTm9Z1A',
#   'channel_url': 'https://www.youtube.com/channel/UCJKYubtV1bfbhS-SxTm9Z1A',
#   'cluster': 0,
#   'cluster_name': 'english, study, big, harvard, brown'},
#  {'channel_id': 'UCJSTwVNFY25vFlnNKwYOKuw',
#   'channel_url': 'https://www.youtube.com/channel/UCJSTwVNFY25vFlnNKwYOKuw',
#   'cluster': 23,
#   'cluster_name': 'echosmith, shuba, ed, music, sheeran'},
#  {'channel_id': 'UCJX8Wn6opMsBng3QWh0dK6g',
#   'channel_url': 'https://www.youtube.com/channel/UCJX8Wn6opMsBng3QWh0dK6g',
#   'cluster': 9,
#   'cluster_name': 'dubai, amish, dignity, nas, zaidalit'},
#  {'channel_id': 'UCJsUvAqDzczYv2UpFmu4PcA',
#   'channel_url': 'https://www.youtube.com/channel/UCJsUvAqDzczYv2UpFmu4PcA',
#   'cluster': 9,
#   'cluster_name': 'dubai, amish, dignity, nas, zaidalit'},
#  {'channel_id': 'UCK7tptUDHh-RYDsdxO1-5QQ',
#   'channel_url': 'https://www.youtube.com/channel/UCK7tptUDHh-RYDsdxO1-5QQ',
#   'cluster': 13,
#   'cluster_name': 'vice, documentary, news, history, world'},
#  {'channel_id': 'UCKIZijugeVt92lbP5YTwMiA',
#   'channel_url': 'https://www.youtube.com/channel/UCKIZijugeVt92lbP5YTwMiA',
#   'cluster': 5,
#   'cluster_name': 'mantra, bhajan, shiva, durga, sai'},
#  {'channel_id': 'UCKL_fwNBR9b4M5Bgyad3KUw',
#   'channel_url': 'https://www.youtube.com/channel/UCKL_fwNBR9b4M5Bgyad3KUw',
#   'cluster': 32,
#   'cluster_name': 'product, management, marketing, sales, carey'},
#  {'channel_id': 'UCKQvGU-qtjEthINeViNbn6A',
#   'channel_url': 'https://www.youtube.com/channel/UCKQvGU-qtjEthINeViNbn6A',
#   'cluster': 3,
#   'cluster_name': 'bloomberg, news, bitcoin, economy, economics'},
#  {'channel_id': 'UCKUs5_UjbfEmiPKgEaWH4Rw',
#   'channel_url': 'https://www.youtube.com/channel/UCKUs5_UjbfEmiPKgEaWH4Rw',
#   'cluster': 9,
#   'cluster_name': 'dubai, amish, dignity, nas, zaidalit'},
#  {'channel_id': 'UCKZozRVHRYsYHGEyNKuhhdA',
#   'channel_url': 'https://www.youtube.com/channel/UCKZozRVHRYsYHGEyNKuhhdA',
#   'cluster': 1,
#   'cluster_name': 'india, defence, indian, upsc, ias'},
#  {'channel_id': 'UCK_ungzYZjsoeuCvzv8RTog',
#   'channel_url': 'https://www.youtube.com/channel/UCK_ungzYZjsoeuCvzv8RTog',
#   'cluster': 2,
#   'cluster_name': 'songs, song, music, cover, mishra'},
#  {'channel_id': 'UCKcWSiffY8MpZ3NKav8LeRA',
#   'channel_url': 'https://www.youtube.com/channel/UCKcWSiffY8MpZ3NKav8LeRA',
#   'cluster': 7,
#   'cluster_name': 'workout, fitness, healthy, calisthenics, dr'},
#  {'channel_id': 'UCKyZ2QnNEtQlN13FvOcSGDw',
#   'channel_url': 'https://www.youtube.com/channel/UCKyZ2QnNEtQlN13FvOcSGDw',
#   'cluster': 5,
#   'cluster_name': 'mantra, bhajan, shiva, durga, sai'},
#  {'channel_id': 'UCKzsU94h-PkLBiF5xHo-SjQ',
#   'channel_url': 'https://www.youtube.com/channel/UCKzsU94h-PkLBiF5xHo-SjQ',
#   'cluster': 29,
#   'cluster_name': 'healing, attraction, law, shivani, pranic'},
#  {'channel_id': 'UCL0ZOT3eKp4RvKcQyBZJ4bw',
#   'channel_url': 'https://www.youtube.com/channel/UCL0ZOT3eKp4RvKcQyBZJ4bw',
#   'cluster': 16,
#   'cluster_name': 'gre, toefl, ielts, test, vocabulary'},
#  {'channel_id': 'UCL8w_A8p8P1HWI3k6PR5Z6w',
#   'channel_url': 'https://www.youtube.com/channel/UCL8w_A8p8P1HWI3k6PR5Z6w',
#   'cluster': 3,
#   'cluster_name': 'bloomberg, news, bitcoin, economy, economics'},
#  {'channel_id': 'UCLPHopoiGPUwr8JHpXxBQ9A',
#   'channel_url': 'https://www.youtube.com/channel/UCLPHopoiGPUwr8JHpXxBQ9A',
#   'cluster': 30,
#   'cluster_name': 'kannada, comedy, funny, vines, prank'},
#  {'channel_id': 'UCL_f53ZEJxp8TtlOkHwMV9Q',
#   'channel_url': 'https://www.youtube.com/channel/UCL_f53ZEJxp8TtlOkHwMV9Q',
#   'cluster': 10,
#   'cluster_name': 'peterson, jordan, personality, psychology, clips'},
#  {'channel_id': 'UCLeJH3qDdggwMFS6z0I4jbw',
#   'channel_url': 'https://www.youtube.com/channel/UCLeJH3qDdggwMFS6z0I4jbw',
#   'cluster': 23,
#   'cluster_name': 'echosmith, shuba, ed, music, sheeran'},
#  {'channel_id': 'UCLo66QVfEod0nNM_GzKNxmQ',
#   'channel_url': 'https://www.youtube.com/channel/UCLo66QVfEod0nNM_GzKNxmQ',
#   'cluster': 3,
#   'cluster_name': 'bloomberg, news, bitcoin, economy, economics'},
#  {'channel_id': 'UCLyr-hfWVCKHcZjV5fg3jbw',
#   'channel_url': 'https://www.youtube.com/channel/UCLyr-hfWVCKHcZjV5fg3jbw',
#   'cluster': 0,
#   'cluster_name': 'english, study, big, harvard, brown'},
#  {'channel_id': 'UCLz7LG4YVi7_iyk4yOARcxA',
#   'channel_url': 'https://www.youtube.com/channel/UCLz7LG4YVi7_iyk4yOARcxA',
#   'cluster': 33,
#   'cluster_name': 'python, google, dash, software, programming'},
#  {'channel_id': 'UCM1VesJtJ9vTXcMLLr_FfdQ',
#   'channel_url': 'https://www.youtube.com/channel/UCM1VesJtJ9vTXcMLLr_FfdQ',
#   'cluster': 2,
#   'cluster_name': 'songs, song, music, cover, mishra'},
#  {'channel_id': 'UCM4d4vlR_63WQJv6UxTwZqg',
#   'channel_url': 'https://www.youtube.com/channel/UCM4d4vlR_63WQJv6UxTwZqg',
#   'cluster': 19,
#   'cluster_name': 'job, shorts, career, work, iit'},
#  {'channel_id': 'UCM5RA4WAMWhtX3okNzjWr_w',
#   'channel_url': 'https://www.youtube.com/channel/UCM5RA4WAMWhtX3okNzjWr_w',
#   'cluster': 1,
#   'cluster_name': 'india, defence, indian, upsc, ias'},
#  {'channel_id': 'UCM7UnDj_L5jBnSXpcDWI9tg',
#   'channel_url': 'https://www.youtube.com/channel/UCM7UnDj_L5jBnSXpcDWI9tg',
#   'cluster': 8,
#   'cluster_name': 'india, sadhguru, google, canada, indian'},
#  {'channel_id': 'UCMV3aTOwUtG5vwfH9_rzb2w',
#   'channel_url': 'https://www.youtube.com/channel/UCMV3aTOwUtG5vwfH9_rzb2w',
#   'cluster': 0,
#   'cluster_name': 'english, study, big, harvard, brown'},
#  {'channel_id': 'UCMkVkFlYZCqkmLLXwPXAFqw',
#   'channel_url': 'https://www.youtube.com/channel/UCMkVkFlYZCqkmLLXwPXAFqw',
#   'cluster': 25,
#   'cluster_name': 'kold, animals, kolder, tides, shifting'},
#  {'channel_id': 'UCMwo6hT5hI3R56rO2HYP-wQ',
#   'channel_url': 'https://www.youtube.com/channel/UCMwo6hT5hI3R56rO2HYP-wQ',
#   'cluster': 0,
#   'cluster_name': 'english, study, big, harvard, brown'},
#  {'channel_id': 'UCN0Ot_4JS6MiYk4BrT6Sgxw',
#   'channel_url': 'https://www.youtube.com/channel/UCN0Ot_4JS6MiYk4BrT6Sgxw',
#   'cluster': 23,
#   'cluster_name': 'echosmith, shuba, ed, music, sheeran'},
#  {'channel_id': 'UCNJUhkpXnF1GcItcztJM-Ww',
#   'channel_url': 'https://www.youtube.com/channel/UCNJUhkpXnF1GcItcztJM-Ww',
#   'cluster': 30,
#   'cluster_name': 'kannada, comedy, funny, vines, prank'},
#  {'channel_id': 'UCNLvvsB75P4VMubocS3dlmg',
#   'channel_url': 'https://www.youtube.com/channel/UCNLvvsB75P4VMubocS3dlmg',
#   'cluster': 26,
#   'cluster_name': 'subliminal, affirmations, meditation, mind, hypnosis'},
#  {'channel_id': 'UCNU_lfiiWBdtULKOw6X0Dig',
#   'channel_url': 'https://www.youtube.com/channel/UCNU_lfiiWBdtULKOw6X0Dig',
#   'cluster': 18,
#   'cluster_name': 'data, science, learning, google, tensorflow'},
#  {'channel_id': 'UCNn6AaHharXIbkRleXGboiQ',
#   'channel_url': 'https://www.youtube.com/channel/UCNn6AaHharXIbkRleXGboiQ',
#   'cluster': 30,
#   'cluster_name': 'kannada, comedy, funny, vines, prank'},
#  {'channel_id': 'UCO3xnVTHzB7l-nc8mABUJIQ',
#   'channel_url': 'https://www.youtube.com/channel/UCO3xnVTHzB7l-nc8mABUJIQ',
#   'cluster': 4,
#   'cluster_name': 'quantum, holes, flammy, integral, interpretation'},
#  {'channel_id': 'UCOR-iqlcedb8VMnax37m3MQ',
#   'channel_url': 'https://www.youtube.com/channel/UCOR-iqlcedb8VMnax37m3MQ',
#   'cluster': 6,
#   'cluster_name': 'music, guitar, berklee, ukulele, flute'},
#  {'channel_id': 'UCOa104QrplnxBkVnoArabwQ',
#   'channel_url': 'https://www.youtube.com/channel/UCOa104QrplnxBkVnoArabwQ',
#   'cluster': 3,
#   'cluster_name': 'bloomberg, news, bitcoin, economy, economics'},
#  {'channel_id': 'UCOaiVpNH05aP0hom0SovBYA',
#   'channel_url': 'https://www.youtube.com/channel/UCOaiVpNH05aP0hom0SovBYA',
#   'cluster': 2,
#   'cluster_name': 'songs, song, music, cover, mishra'},
#  {'channel_id': 'UCObk_g1hQBy0RKKriVX_zOQ',
#   'channel_url': 'https://www.youtube.com/channel/UCObk_g1hQBy0RKKriVX_zOQ',
#   'cluster': 14,
#   'cluster_name': 'comedy, trevor, noah, funny, netflix'},
#  {'channel_id': 'UCOw4v1j3QnzH7X4krQAS7fg',
#   'channel_url': 'https://www.youtube.com/channel/UCOw4v1j3QnzH7X4krQAS7fg',
#   'cluster': 23,
#   'cluster_name': 'echosmith, shuba, ed, music, sheeran'},
#  {'channel_id': 'UCP5tjEmvPItGyLhmjdwP7Ww',
#   'channel_url': 'https://www.youtube.com/channel/UCP5tjEmvPItGyLhmjdwP7Ww',
#   'cluster': 13,
#   'cluster_name': 'vice, documentary, news, history, world'},
#  {'channel_id': 'UCP6HGa63sBC7-KHtkme-p-g',
#   'channel_url': 'https://www.youtube.com/channel/UCP6HGa63sBC7-KHtkme-p-g',
#   'cluster': 15,
#   'cluster_name': 'documentary, telegraph, bbc, tv, news'},
#  {'channel_id': 'UCP8dEm4e63fY8rG-cQXgo7A',
#   'channel_url': 'https://www.youtube.com/channel/UCP8dEm4e63fY8rG-cQXgo7A',
#   'cluster': 11,
#   'cluster_name': 'prank, shorts, onlyjayus, iphone, vrchat'},
#  {'channel_id': 'UCPgLNge0xqQHWM5B5EFH9Cg',
#   'channel_url': 'https://www.youtube.com/channel/UCPgLNge0xqQHWM5B5EFH9Cg',
#   'cluster': 15,
#   'cluster_name': 'documentary, telegraph, bbc, tv, news'},
#  {'channel_id': 'UCPxMZIFE856tbTfdkdjzTSQ',
#   'channel_url': 'https://www.youtube.com/channel/UCPxMZIFE856tbTfdkdjzTSQ',
#   'cluster': 8,
#   'cluster_name': 'india, sadhguru, google, canada, indian'},
#  {'channel_id': 'UCPzCBQC5-hWRmK5DbLSysdw',
#   'channel_url': 'https://www.youtube.com/channel/UCPzCBQC5-hWRmK5DbLSysdw',
#   'cluster': 5,
#   'cluster_name': 'mantra, bhajan, shiva, durga, sai'},
#  {'channel_id': 'UCQ93iDLSWgc_7o4AOHxkn8Q',
#   'channel_url': 'https://www.youtube.com/channel/UCQ93iDLSWgc_7o4AOHxkn8Q',
#   'cluster': 30,
#   'cluster_name': 'kannada, comedy, funny, vines, prank'},
#  {'channel_id': 'UCQA9tK0nRK1e_Bqg0uETs8A',
#   'channel_url': 'https://www.youtube.com/channel/UCQA9tK0nRK1e_Bqg0uETs8A',
#   'cluster': 1,
#   'cluster_name': 'india, defence, indian, upsc, ias'},
#  {'channel_id': 'UCQEkgUtOXa-1PSzg4fC_H8g',
#   'channel_url': 'https://www.youtube.com/channel/UCQEkgUtOXa-1PSzg4fC_H8g',
#   'cluster': 20,
#   'cluster_name': 'usa, abroad, dallas, student, visa'},
#  {'channel_id': 'UCQRELbX0H5FCokIFxOAsHFA',
#   'channel_url': 'https://www.youtube.com/channel/UCQRELbX0H5FCokIFxOAsHFA',
#   'cluster': 6,
#   'cluster_name': 'music, guitar, berklee, ukulele, flute'},
#  {'channel_id': 'UCQdyCrZpGq4Bbu6V8LPUDWg',
#   'channel_url': 'https://www.youtube.com/channel/UCQdyCrZpGq4Bbu6V8LPUDWg',
#   'cluster': 29,
#   'cluster_name': 'healing, attraction, law, shivani, pranic'},
#  {'channel_id': 'UCQzHhoWHxmRS07TFx2D7lpQ',
#   'channel_url': 'https://www.youtube.com/channel/UCQzHhoWHxmRS07TFx2D7lpQ',
#   'cluster': 28,
#   'cluster_name': 'startup, design, entrepreneurship, startups, sales'},
#  {'channel_id': 'UCR4wTAyVbbX-IiBiGCgIBTg',
#   'channel_url': 'https://www.youtube.com/channel/UCR4wTAyVbbX-IiBiGCgIBTg',
#   'cluster': 14,
#   'cluster_name': 'comedy, trevor, noah, funny, netflix'},
#  {'channel_id': 'UCRJGywIBeuhtRKeIEj9NGHw',
#   'channel_url': 'https://www.youtube.com/channel/UCRJGywIBeuhtRKeIEj9NGHw',
#   'cluster': 5,
#   'cluster_name': 'mantra, bhajan, shiva, durga, sai'},
#  {'channel_id': 'UCRPMAqdtSgd0Ipeef7iFsKw',
#   'channel_url': 'https://www.youtube.com/channel/UCRPMAqdtSgd0Ipeef7iFsKw',
#   'cluster': 33,
#   'cluster_name': 'python, google, dash, software, programming'},
#  {'channel_id': 'UCRRr_xrOm66qaigIbwFLvbQ',
#   'channel_url': 'https://www.youtube.com/channel/UCRRr_xrOm66qaigIbwFLvbQ',
#   'cluster': 0,
#   'cluster_name': 'english, study, big, harvard, brown'},
#  {'channel_id': 'UCRqWqb-iDlueYhUT98Ouj2A',
#   'channel_url': 'https://www.youtube.com/channel/UCRqWqb-iDlueYhUT98Ouj2A',
#   'cluster': 8,
#   'cluster_name': 'india, sadhguru, google, canada, indian'},
#  {'channel_id': 'UCRsVdVQlP6iNhRZLbzhSMBw',
#   'channel_url': 'https://www.youtube.com/channel/UCRsVdVQlP6iNhRZLbzhSMBw',
#   'cluster': 30,
#   'cluster_name': 'kannada, comedy, funny, vines, prank'},
#  {'channel_id': 'UCS1abmNrZSkWM1vq-sMm63g',
#   'channel_url': 'https://www.youtube.com/channel/UCS1abmNrZSkWM1vq-sMm63g',
#   'cluster': 1,
#   'cluster_name': 'india, defence, indian, upsc, ias'},
#  {'channel_id': 'UCS3dfr0uOIC6OP-rSECVPMA',
#   'channel_url': 'https://www.youtube.com/channel/UCS3dfr0uOIC6OP-rSECVPMA',
#   'cluster': 6,
#   'cluster_name': 'music, guitar, berklee, ukulele, flute'},
#  {'channel_id': 'UCSPYtDyppzYF9KMLZ1A-kOw',
#   'channel_url': 'https://www.youtube.com/channel/UCSPYtDyppzYF9KMLZ1A-kOw',
#   'cluster': 16,
#   'cluster_name': 'gre, toefl, ielts, test, vocabulary'},
#  {'channel_id': 'UCSZBmDk4v3ozB3kfB2oyUEA',
#   'channel_url': 'https://www.youtube.com/channel/UCSZBmDk4v3ozB3kfB2oyUEA',
#   'cluster': 23,
#   'cluster_name': 'echosmith, shuba, ed, music, sheeran'},
#  {'channel_id': 'UCSc6wkH9Jp9zzegKoBViXoQ',
#   'channel_url': 'https://www.youtube.com/channel/UCSc6wkH9Jp9zzegKoBViXoQ',
#   'cluster': 5,
#   'cluster_name': 'mantra, bhajan, shiva, durga, sai'},
#  {'channel_id': 'UCSrnmu3W6YXWU_85DKT5arg',
#   'channel_url': 'https://www.youtube.com/channel/UCSrnmu3W6YXWU_85DKT5arg',
#   'cluster': 11,
#   'cluster_name': 'prank, shorts, onlyjayus, iphone, vrchat'},
#  {'channel_id': 'UCStOJC8F-Zn_oxeMi2lfQog',
#   'channel_url': 'https://www.youtube.com/channel/UCStOJC8F-Zn_oxeMi2lfQog',
#   'cluster': 15,
#   'cluster_name': 'documentary, telegraph, bbc, tv, news'},
#  {'channel_id': 'UCSw5U1MuzDED2Nvlx9m65-Q',
#   'channel_url': 'https://www.youtube.com/channel/UCSw5U1MuzDED2Nvlx9m65-Q',
#   'cluster': 0,
#   'cluster_name': 'english, study, big, harvard, brown'},
#  {'channel_id': 'UCT3v6vL2H5HK4loLMc8pmCw',
#   'channel_url': 'https://www.youtube.com/channel/UCT3v6vL2H5HK4loLMc8pmCw',
#   'cluster': 21,
#   'cluster_name': 'ukraine, russia, news, tldr, chomsky'},
#  {'channel_id': 'UCT4iTe4eB9aRn2p3jRuGlDA',
#   'channel_url': 'https://www.youtube.com/channel/UCT4iTe4eB9aRn2p3jRuGlDA',
#   'cluster': 19,
#   'cluster_name': 'job, shorts, career, work, iit'},
#  {'channel_id': 'UCT8M_hDfTRjUbs8hwahZyBA',
#   'channel_url': 'https://www.youtube.com/channel/UCT8M_hDfTRjUbs8hwahZyBA',
#   'cluster': 5,
#   'cluster_name': 'mantra, bhajan, shiva, durga, sai'},
#  {'channel_id': 'UCTrSsPMmZavLbc3Ex7VhjDg',
#   'channel_url': 'https://www.youtube.com/channel/UCTrSsPMmZavLbc3Ex7VhjDg',
#   'cluster': 17,
#   'cluster_name': 'shooting, gun, glock, review, ak'},
#  {'channel_id': 'UCUFFHXvzAMRSD8Bq4bJppxQ',
#   'channel_url': 'https://www.youtube.com/channel/UCUFFHXvzAMRSD8Bq4bJppxQ',
#   'cluster': 0,
#   'cluster_name': 'english, study, big, harvard, brown'},
#  {'channel_id': 'UCUKTrXf8KdGIVXudO3dqOWw',
#   'channel_url': 'https://www.youtube.com/channel/UCUKTrXf8KdGIVXudO3dqOWw',
#   'cluster': 8,
#   'cluster_name': 'india, sadhguru, google, canada, indian'},
#  {'channel_id': 'UCUMVRo_qY2RKrEweB9rCv6g',
#   'channel_url': 'https://www.youtube.com/channel/UCUMVRo_qY2RKrEweB9rCv6g',
#   'cluster': 11,
#   'cluster_name': 'prank, shorts, onlyjayus, iphone, vrchat'},
#  {'channel_id': 'UCUMZ7gohGI9HcU9VNsr2FJQ',
#   'channel_url': 'https://www.youtube.com/channel/UCUMZ7gohGI9HcU9VNsr2FJQ',
#   'cluster': 3,
#   'cluster_name': 'bloomberg, news, bitcoin, economy, economics'},
#  {'channel_id': 'UCUh6k9ReBf1GTLCHRHDI2pw',
#   'channel_url': 'https://www.youtube.com/channel/UCUh6k9ReBf1GTLCHRHDI2pw',
#   'cluster': 26,
#   'cluster_name': 'subliminal, affirmations, meditation, mind, hypnosis'},
#  {'channel_id': 'UCUsN5ZwHx2kILm84-jPDeXw',
#   'channel_url': 'https://www.youtube.com/channel/UCUsN5ZwHx2kILm84-jPDeXw',
#   'cluster': 14,
#   'cluster_name': 'comedy, trevor, noah, funny, netflix'},
#  {'channel_id': 'UCUwSeY7lUdZSP0vuflq1oPA',
#   'channel_url': 'https://www.youtube.com/channel/UCUwSeY7lUdZSP0vuflq1oPA',
#   'cluster': 2,
#   'cluster_name': 'songs, song, music, cover, mishra'},
#  {'channel_id': 'UCUxc0iEpV8wZV4WLOui0RwQ',
#   'channel_url': 'https://www.youtube.com/channel/UCUxc0iEpV8wZV4WLOui0RwQ',
#   'cluster': 11,
#   'cluster_name': 'prank, shorts, onlyjayus, iphone, vrchat'},
#  {'channel_id': 'UCUz48nBLEvfE-2rtjuHLt4A',
#   'channel_url': 'https://www.youtube.com/channel/UCUz48nBLEvfE-2rtjuHLt4A',
#   'cluster': 2,
#   'cluster_name': 'songs, song, music, cover, mishra'},
#  {'channel_id': 'UCV0DVncZjaudmyfZRrLZXVg',
#   'channel_url': 'https://www.youtube.com/channel/UCV0DVncZjaudmyfZRrLZXVg',
#   'cluster': 5,
#   'cluster_name': 'mantra, bhajan, shiva, durga, sai'},
#  {'channel_id': 'UCV5mGxp-rtsGDAedDYnp7hA',
#   'channel_url': 'https://www.youtube.com/channel/UCV5mGxp-rtsGDAedDYnp7hA',
#   'cluster': 11,
#   'cluster_name': 'prank, shorts, onlyjayus, iphone, vrchat'},
#  {'channel_id': 'UCV8Qe8z3RDLiAV7E0WP7-Fg',
#   'channel_url': 'https://www.youtube.com/channel/UCV8Qe8z3RDLiAV7E0WP7-Fg',
#   'cluster': 11,
#   'cluster_name': 'prank, shorts, onlyjayus, iphone, vrchat'},
#  {'channel_id': 'UCVBXum_ntfgHgHCOYtGOmEw',
#   'channel_url': 'https://www.youtube.com/channel/UCVBXum_ntfgHgHCOYtGOmEw',
#   'cluster': 9,
#   'cluster_name': 'dubai, amish, dignity, nas, zaidalit'},
#  {'channel_id': 'UCVNDbT7AQX7WZMIR2tZdYDg',
#   'channel_url': 'https://www.youtube.com/channel/UCVNDbT7AQX7WZMIR2tZdYDg',
#   'cluster': 9,
#   'cluster_name': 'dubai, amish, dignity, nas, zaidalit'},
#  {'channel_id': 'UCVcIkmIS1R8JM8Xm2ng9_PQ',
#   'channel_url': 'https://www.youtube.com/channel/UCVcIkmIS1R8JM8Xm2ng9_PQ',
#   'cluster': 8,
#   'cluster_name': 'india, sadhguru, google, canada, indian'},
#  {'channel_id': 'UCVpjKK6JMtlAP3cfBjduTxw',
#   'channel_url': 'https://www.youtube.com/channel/UCVpjKK6JMtlAP3cfBjduTxw',
#   'cluster': 27,
#   'cluster_name': 'immigration, card, green, visa, hb'},
#  {'channel_id': 'UCVv7h9KKcQ5B6KFVHOhZl4Q',
#   'channel_url': 'https://www.youtube.com/channel/UCVv7h9KKcQ5B6KFVHOhZl4Q',
#   'cluster': 6,
#   'cluster_name': 'music, guitar, berklee, ukulele, flute'},
#  {'channel_id': 'UCWHCXSKASuSzao_pplQ7SPw',
#   'channel_url': 'https://www.youtube.com/channel/UCWHCXSKASuSzao_pplQ7SPw',
#   'cluster': 24,
#   'cluster_name': 'sbi, rachana, market, ca, card'},
#  {'channel_id': 'UCWX0cUR2rZcqKei1Vstww-A',
#   'channel_url': 'https://www.youtube.com/channel/UCWX0cUR2rZcqKei1Vstww-A',
#   'cluster': 33,
#   'cluster_name': 'python, google, dash, software, programming'},
#  {'channel_id': 'UCWXYdNyGX01rnTB-tQci8JQ',
#   'channel_url': 'https://www.youtube.com/channel/UCWXYdNyGX01rnTB-tQci8JQ',
#   'cluster': 2,
#   'cluster_name': 'songs, song, music, cover, mishra'},
#  {'channel_id': 'UCWo4IA01TXzBeGJJKWHOG9g',
#   'channel_url': 'https://www.youtube.com/channel/UCWo4IA01TXzBeGJJKWHOG9g',
#   'cluster': 0,
#   'cluster_name': 'english, study, big, harvard, brown'},
#  {'channel_id': 'UCWtWeBSsUpYkLnGGyHDSiOQ',
#   'channel_url': 'https://www.youtube.com/channel/UCWtWeBSsUpYkLnGGyHDSiOQ',
#   'cluster': 32,
#   'cluster_name': 'product, management, marketing, sales, carey'},
#  {'channel_id': 'UCXGiCLn-Xh9VwDT8h06rOIA',
#   'channel_url': 'https://www.youtube.com/channel/UCXGiCLn-Xh9VwDT8h06rOIA',
#   'cluster': 6,
#   'cluster_name': 'music, guitar, berklee, ukulele, flute'},
#  {'channel_id': 'UCXMVaxrax7RNDPdfRrXXgtQ',
#   'channel_url': 'https://www.youtube.com/channel/UCXMVaxrax7RNDPdfRrXXgtQ',
#   'cluster': 0,
#   'cluster_name': 'english, study, big, harvard, brown'},
#  {'channel_id': 'UCXUrDDdmQHni2UTSNyIh4ag',
#   'channel_url': 'https://www.youtube.com/channel/UCXUrDDdmQHni2UTSNyIh4ag',
#   'cluster': 11,
#   'cluster_name': 'prank, shorts, onlyjayus, iphone, vrchat'},
#  {'channel_id': 'UCY1kMZp36IQSyNx_9h4mpCg',
#   'channel_url': 'https://www.youtube.com/channel/UCY1kMZp36IQSyNx_9h4mpCg',
#   'cluster': 0,
#   'cluster_name': 'english, study, big, harvard, brown'},
#  {'channel_id': 'UCY6N8zZhs2V7gNTUxPuKWoQ',
#   'channel_url': 'https://www.youtube.com/channel/UCY6N8zZhs2V7gNTUxPuKWoQ',
#   'cluster': 33,
#   'cluster_name': 'python, google, dash, software, programming'},
#  {'channel_id': 'UCYCAYFgoaBn8vzRYXHuTZiA',
#   'channel_url': 'https://www.youtube.com/channel/UCYCAYFgoaBn8vzRYXHuTZiA',
#   'cluster': 29,
#   'cluster_name': 'healing, attraction, law, shivani, pranic'},
#  {'channel_id': 'UCYLR1ghzYNyvfjw78raCuxA',
#   'channel_url': 'https://www.youtube.com/channel/UCYLR1ghzYNyvfjw78raCuxA',
#   'cluster': 14,
#   'cluster_name': 'comedy, trevor, noah, funny, netflix'},
#  {'channel_id': 'UCYO_jab_esuFRV4b17AJtAw',
#   'channel_url': 'https://www.youtube.com/channel/UCYO_jab_esuFRV4b17AJtAw',
#   'cluster': 0,
#   'cluster_name': 'english, study, big, harvard, brown'},
#  {'channel_id': 'UCYXhaLEoRfUc34MPSx4HpDw',
#   'channel_url': 'https://www.youtube.com/channel/UCYXhaLEoRfUc34MPSx4HpDw',
#   'cluster': 14,
#   'cluster_name': 'comedy, trevor, noah, funny, netflix'},
#  {'channel_id': 'UCYc3JNvtOfwHWU_DSByJm2g',
#   'channel_url': 'https://www.youtube.com/channel/UCYc3JNvtOfwHWU_DSByJm2g',
#   'cluster': 30,
#   'cluster_name': 'kannada, comedy, funny, vines, prank'},
#  {'channel_id': 'UCYwVxWpjeKFWwu8TML-Te9A',
#   'channel_url': 'https://www.youtube.com/channel/UCYwVxWpjeKFWwu8TML-Te9A',
#   'cluster': 18,
#   'cluster_name': 'data, science, learning, google, tensorflow'},
#  {'channel_id': 'UCZ4AMrDcNrfy3X6nsU8-rPg',
#   'channel_url': 'https://www.youtube.com/channel/UCZ4AMrDcNrfy3X6nsU8-rPg',
#   'cluster': 3,
#   'cluster_name': 'bloomberg, news, bitcoin, economy, economics'},
#  {'channel_id': 'UCZ4sGYJ6l0cgnVNIHY8GY6w',
#   'channel_url': 'https://www.youtube.com/channel/UCZ4sGYJ6l0cgnVNIHY8GY6w',
#   'cluster': 16,
#   'cluster_name': 'gre, toefl, ielts, test, vocabulary'},
#  {'channel_id': 'UCZ7x7yDBbEFCGztD8BYvRhA',
#   'channel_url': 'https://www.youtube.com/channel/UCZ7x7yDBbEFCGztD8BYvRhA',
#   'cluster': 3,
#   'cluster_name': 'bloomberg, news, bitcoin, economy, economics'},
#  {'channel_id': 'UCZC45sBWNdkqSQ9Bwtt5lfA',
#   'channel_url': 'https://www.youtube.com/channel/UCZC45sBWNdkqSQ9Bwtt5lfA',
#   'cluster': 22,
#   'cluster_name': 'dating, gabblin, hussey, men, relationship'},
#  {'channel_id': 'UCZGmXbsgs0cd8NXk6VrF8wQ',
#   'channel_url': 'https://www.youtube.com/channel/UCZGmXbsgs0cd8NXk6VrF8wQ',
#   'cluster': 9,
#   'cluster_name': 'dubai, amish, dignity, nas, zaidalit'},
#  {'channel_id': 'UCZJSg5r9IBgknv0VQAVoETg',
#   'channel_url': 'https://www.youtube.com/channel/UCZJSg5r9IBgknv0VQAVoETg',
#   'cluster': 5,
#   'cluster_name': 'mantra, bhajan, shiva, durga, sai'},
#  {'channel_id': 'UCZaT_X_mc0BI-djXOlfhqWQ',
#   'channel_url': 'https://www.youtube.com/channel/UCZaT_X_mc0BI-djXOlfhqWQ',
#   'cluster': 13,
#   'cluster_name': 'vice, documentary, news, history, world'},
#  {'channel_id': 'UC_gUM8rL-Lrg6O3adPW9K1g',
#   'channel_url': 'https://www.youtube.com/channel/UC_gUM8rL-Lrg6O3adPW9K1g',
#   'cluster': 21,
#   'cluster_name': 'ukraine, russia, news, tldr, chomsky'},
#  {'channel_id': 'UC_hoQDD6zKcIqpIYLsFbBeA',
#   'channel_url': 'https://www.youtube.com/channel/UC_hoQDD6zKcIqpIYLsFbBeA',
#   'cluster': 9,
#   'cluster_name': 'dubai, amish, dignity, nas, zaidalit'},
#  {'channel_id': 'UC_tXKhJlqZrgr_qdhEKmrDQ',
#   'channel_url': 'https://www.youtube.com/channel/UC_tXKhJlqZrgr_qdhEKmrDQ',
#   'cluster': 25,
#   'cluster_name': 'kold, animals, kolder, tides, shifting'},
#  {'channel_id': 'UC_vMxkZeIEQXK8snsBCOlpw',
#   'channel_url': 'https://www.youtube.com/channel/UC_vMxkZeIEQXK8snsBCOlpw',
#   'cluster': 30,
#   'cluster_name': 'kannada, comedy, funny, vines, prank'},
#  {'channel_id': 'UC_zmsIHN2KoCHI82Cl2S-FA',
#   'channel_url': 'https://www.youtube.com/channel/UC_zmsIHN2KoCHI82Cl2S-FA',
#   'cluster': 14,
#   'cluster_name': 'comedy, trevor, noah, funny, netflix'},
#  {'channel_id': 'UCa2OR2nl26Ht0Gg_IkCd7DQ',
#   'channel_url': 'https://www.youtube.com/channel/UCa2OR2nl26Ht0Gg_IkCd7DQ',
#   'cluster': 6,
#   'cluster_name': 'music, guitar, berklee, ukulele, flute'},
#  {'channel_id': 'UCa6M_MhZv_NEyXDffvnKikQ',
#   'channel_url': 'https://www.youtube.com/channel/UCa6M_MhZv_NEyXDffvnKikQ',
#   'cluster': 29,
#   'cluster_name': 'healing, attraction, law, shivani, pranic'},
#  {'channel_id': 'UCa9852OG1OJwMYAi7Arb2ag',
#   'channel_url': 'https://www.youtube.com/channel/UCa9852OG1OJwMYAi7Arb2ag',
#   'cluster': 6,
#   'cluster_name': 'music, guitar, berklee, ukulele, flute'},
#  {'channel_id': 'UCaF3MVnBYNnjAKF16k3mUjw',
#   'channel_url': 'https://www.youtube.com/channel/UCaF3MVnBYNnjAKF16k3mUjw',
#   'cluster': 5,
#   'cluster_name': 'mantra, bhajan, shiva, durga, sai'},
#  {'channel_id': 'UCaIx0hBYAl-6gl_KjyTgObQ',
#   'channel_url': 'https://www.youtube.com/channel/UCaIx0hBYAl-6gl_KjyTgObQ',
#   'cluster': 8,
#   'cluster_name': 'india, sadhguru, google, canada, indian'},
#  {'channel_id': 'UCaROuOh08EiaIqQ8Apka2Yw',
#   'channel_url': 'https://www.youtube.com/channel/UCaROuOh08EiaIqQ8Apka2Yw',
#   'cluster': 27,
#   'cluster_name': 'immigration, card, green, visa, hb'},
#  {'channel_id': 'UCafpueX9hFLls24ed6UddEQ',
#   'channel_url': 'https://www.youtube.com/channel/UCafpueX9hFLls24ed6UddEQ',
#   'cluster': 1,
#   'cluster_name': 'india, defence, indian, upsc, ias'},
#  {'channel_id': 'UCarEovlrD9QY-fy-Z6apIDQ',
#   'channel_url': 'https://www.youtube.com/channel/UCarEovlrD9QY-fy-Z6apIDQ',
#   'cluster': 14,
#   'cluster_name': 'comedy, trevor, noah, funny, netflix'},
#  {'channel_id': 'UCayzTot0bZq1U5NUNhvNDdQ',
#   'channel_url': 'https://www.youtube.com/channel/UCayzTot0bZq1U5NUNhvNDdQ',
#   'cluster': 6,
#   'cluster_name': 'music, guitar, berklee, ukulele, flute'},
#  {'channel_id': 'UCb7xZQi7F3RW7BNtR57cNnA',
#   'channel_url': 'https://www.youtube.com/channel/UCb7xZQi7F3RW7BNtR57cNnA',
#   'cluster': 13,
#   'cluster_name': 'vice, documentary, news, history, world'},
#  {'channel_id': 'UCbzwtpaN0stcTVb8aCbLq0A',
#   'channel_url': 'https://www.youtube.com/channel/UCbzwtpaN0stcTVb8aCbLq0A',
#   'cluster': 20,
#   'cluster_name': 'usa, abroad, dallas, student, visa'},
#  {'channel_id': 'UCcYzLCs3zrQIBVHYA1sK2sw',
#   'channel_url': 'https://www.youtube.com/channel/UCcYzLCs3zrQIBVHYA1sK2sw',
#   'cluster': 8,
#   'cluster_name': 'india, sadhguru, google, canada, indian'},
#  {'channel_id': 'UCcefcZRL2oaA_uBNeo5UOWg',
#   'channel_url': 'https://www.youtube.com/channel/UCcefcZRL2oaA_uBNeo5UOWg',
#   'cluster': 28,
#   'cluster_name': 'startup, design, entrepreneurship, startups, sales'},
#  {'channel_id': 'UCd3rCGu_2R_5LN6IcCBHIQA',
#   'channel_url': 'https://www.youtube.com/channel/UCd3rCGu_2R_5LN6IcCBHIQA',
#   'cluster': 17,
#   'cluster_name': 'shooting, gun, glock, review, ak'},
#  {'channel_id': 'UCdC0An4ZPNr_YiFiYoVbwaw',
#   'channel_url': 'https://www.youtube.com/channel/UCdC0An4ZPNr_YiFiYoVbwaw',
#   'cluster': 11,
#   'cluster_name': 'prank, shorts, onlyjayus, iphone, vrchat'},
#  {'channel_id': 'UCdWiqyd8RMx_qhCadO19k0g',
#   'channel_url': 'https://www.youtube.com/channel/UCdWiqyd8RMx_qhCadO19k0g',
#   'cluster': 14,
#   'cluster_name': 'comedy, trevor, noah, funny, netflix'},
#  {'channel_id': 'UCdnPPbjGZiX7Dw56YDYVDsg',
#   'channel_url': 'https://www.youtube.com/channel/UCdnPPbjGZiX7Dw56YDYVDsg',
#   'cluster': 2,
#   'cluster_name': 'songs, song, music, cover, mishra'},
#  {'channel_id': 'UCdxi8d8qRsRyUi2ERYjYb-w',
#   'channel_url': 'https://www.youtube.com/channel/UCdxi8d8qRsRyUi2ERYjYb-w',
#   'cluster': 3,
#   'cluster_name': 'bloomberg, news, bitcoin, economy, economics'},
#  {'channel_id': 'UCe3qdG0A_gr-sEdat5y2twQ',
#   'channel_url': 'https://www.youtube.com/channel/UCe3qdG0A_gr-sEdat5y2twQ',
#   'cluster': 24,
#   'cluster_name': 'sbi, rachana, market, ca, card'},
#  {'channel_id': 'UCeJFgNahi--FKs0oJyeRDEw',
#   'channel_url': 'https://www.youtube.com/channel/UCeJFgNahi--FKs0oJyeRDEw',
#   'cluster': 7,
# ...
#  {'channel_id': 'UCn8zNIfYAQNdrFRrr8oibKw',
#   'channel_url': 'https://www.youtube.com/channel/UCn8zNIfYAQNdrFRrr8oibKw',
#   'cluster': 13,
#   'cluster_name': 'vice, documentary, news, history, world'},
#  {'channel_id': 'UCnU9c8lf6Cvfz8VkD4fxbVQ',
#   'channel_url': 'https://www.youtube.com/channel/UCnU9c8lf6Cvfz8VkD4fxbVQ',
#   'cluster': 2,
#   'cluster_name': 'songs, song, music, cover, mishra'},
#  {'channel_id': 'UCneQdPbDLwZ__ZXP0YVwiag',
#   'channel_url': 'https://www.youtube.com/channel/UCneQdPbDLwZ__ZXP0YVwiag',
#   'cluster': 3,
#   'cluster_name': 'bloomberg, news, bitcoin, economy, economics'},
#  {'channel_id': 'UCnimG5HX-XSbso0bxpBFH2w',
#   'channel_url': 'https://www.youtube.com/channel/UCnimG5HX-XSbso0bxpBFH2w',
#   'cluster': 2,
#   'cluster_name': 'songs, song, music, cover, mishra'},
#  {'channel_id': 'UCnpB6UZ7U5rKPLEjCHKLgbg',
#   'channel_url': 'https://www.youtube.com/channel/UCnpB6UZ7U5rKPLEjCHKLgbg',
#   'cluster': 22,
#   'cluster_name': 'dating, gabblin, hussey, men, relationship'},
#  {'channel_id': 'UCnpekFV93kB1O0rVqEKSumg',
#   'channel_url': 'https://www.youtube.com/channel/UCnpekFV93kB1O0rVqEKSumg',
#   'cluster': 3,
#   'cluster_name': 'bloomberg, news, bitcoin, economy, economics'},
#  {'channel_id': 'UCo7a6riBFJ3tkeHjvkXPn1g',
#   'channel_url': 'https://www.youtube.com/channel/UCo7a6riBFJ3tkeHjvkXPn1g',
#   'cluster': 3,
#   'cluster_name': 'bloomberg, news, bitcoin, economy, economics'},
#  {'channel_id': 'UCoOjH8D2XAgjzQlneM2W0EQ',
#   'channel_url': 'https://www.youtube.com/channel/UCoOjH8D2XAgjzQlneM2W0EQ',
#   'cluster': 0,
#   'cluster_name': 'english, study, big, harvard, brown'},
#  {'channel_id': 'UCoPGIiWGsVIEGo8DffljpQA',
#   'channel_url': 'https://www.youtube.com/channel/UCoPGIiWGsVIEGo8DffljpQA',
#   'cluster': 30,
#   'cluster_name': 'kannada, comedy, funny, vines, prank'},
#  {'channel_id': 'UCoVwq0vh-XD8RrEyDZ0KeJw',
#   'channel_url': 'https://www.youtube.com/channel/UCoVwq0vh-XD8RrEyDZ0KeJw',
#   'cluster': 8,
#   'cluster_name': 'india, sadhguru, google, canada, indian'},
#  {'channel_id': 'UCodkb-qBktJI5NrUsPYpf7g',
#   'channel_url': 'https://www.youtube.com/channel/UCodkb-qBktJI5NrUsPYpf7g',
#   'cluster': 10,
#   'cluster_name': 'peterson, jordan, personality, psychology, clips'},
#  {'channel_id': 'UCofLyWKImmSHboaerI4AwfA',
#   'channel_url': 'https://www.youtube.com/channel/UCofLyWKImmSHboaerI4AwfA',
#   'cluster': 19,
#   'cluster_name': 'job, shorts, career, work, iit'},
#  {'channel_id': 'UCp8v5KixDUzI8z8crVCXj-g',
#   'channel_url': 'https://www.youtube.com/channel/UCp8v5KixDUzI8z8crVCXj-g',
#   'cluster': 2,
#   'cluster_name': 'songs, song, music, cover, mishra'},
#  {'channel_id': 'UCp9-3fFhiTjcCNxccOJ2vNA',
#   'channel_url': 'https://www.youtube.com/channel/UCp9-3fFhiTjcCNxccOJ2vNA',
#   'cluster': 0,
#   'cluster_name': 'english, study, big, harvard, brown'},
#  {'channel_id': 'UCpDJl2EmP7Oh90Vylx0dZtA',
#   'channel_url': 'https://www.youtube.com/channel/UCpDJl2EmP7Oh90Vylx0dZtA',
#   'cluster': 6,
#   'cluster_name': 'music, guitar, berklee, ukulele, flute'},
#  {'channel_id': 'UCpExuV8qJMfCaSQNL1YG6bQ',
#   'channel_url': 'https://www.youtube.com/channel/UCpExuV8qJMfCaSQNL1YG6bQ',
#   'cluster': 19,
#   'cluster_name': 'job, shorts, career, work, iit'},
#  {'channel_id': 'UCpPZggubTs5NvcMCHfRCVKw',
#   'channel_url': 'https://www.youtube.com/channel/UCpPZggubTs5NvcMCHfRCVKw',
#   'cluster': 23,
#   'cluster_name': 'echosmith, shuba, ed, music, sheeran'},
#  {'channel_id': 'UCpVm7bg6pXKo1Pr6k5kxG9A',
#   'channel_url': 'https://www.youtube.com/channel/UCpVm7bg6pXKo1Pr6k5kxG9A',
#   'cluster': 13,
#   'cluster_name': 'vice, documentary, news, history, world'},
#  {'channel_id': 'UCpip9EesFuO1lkSY_B-vExw',
#   'channel_url': 'https://www.youtube.com/channel/UCpip9EesFuO1lkSY_B-vExw',
#   'cluster': 14,
#   'cluster_name': 'comedy, trevor, noah, funny, netflix'},
#  {'channel_id': 'UCppsTOeeitiiuKIAJcAtEiw',
#   'channel_url': 'https://www.youtube.com/channel/UCppsTOeeitiiuKIAJcAtEiw',
#   'cluster': 19,
#   'cluster_name': 'job, shorts, career, work, iit'},
#  {'channel_id': 'UCptc7b3jk_PtbpLLeZojRZA',
#   'channel_url': 'https://www.youtube.com/channel/UCptc7b3jk_PtbpLLeZojRZA',
#   'cluster': 20,
#   'cluster_name': 'usa, abroad, dallas, student, visa'},
#  {'channel_id': 'UCq-Fj5jknLsUf-MWSy4_brA',
#   'channel_url': 'https://www.youtube.com/channel/UCq-Fj5jknLsUf-MWSy4_brA',
#   'cluster': 2,
#   'cluster_name': 'songs, song, music, cover, mishra'},
#  {'channel_id': 'UCq1tIu-F5fRVdRZ1DHTXc3Q',
#   'channel_url': 'https://www.youtube.com/channel/UCq1tIu-F5fRVdRZ1DHTXc3Q',
#   'cluster': 0,
#   'cluster_name': 'english, study, big, harvard, brown'},
#  {'channel_id': 'UCqBFsuAz41sqWcFjZkqmJqQ',
#   'channel_url': 'https://www.youtube.com/channel/UCqBFsuAz41sqWcFjZkqmJqQ',
#   'cluster': 33,
#   'cluster_name': 'python, google, dash, software, programming'},
#  {'channel_id': 'UCqFzWxSCi39LnW1JKFR3efg',
#   'channel_url': 'https://www.youtube.com/channel/UCqFzWxSCi39LnW1JKFR3efg',
#   'cluster': 14,
#   'cluster_name': 'comedy, trevor, noah, funny, netflix'},
#  {'channel_id': 'UCqTU2-sZlJZppgwb_Z5LXhQ',
#   'channel_url': 'https://www.youtube.com/channel/UCqTU2-sZlJZppgwb_Z5LXhQ',
#   'cluster': 26,
#   'cluster_name': 'subliminal, affirmations, meditation, mind, hypnosis'},
#  {'channel_id': 'UCqWB6EseWbMKnzunyewBDqg',
#   'channel_url': 'https://www.youtube.com/channel/UCqWB6EseWbMKnzunyewBDqg',
#   'cluster': 26,
#   'cluster_name': 'subliminal, affirmations, meditation, mind, hypnosis'},
#  {'channel_id': 'UCqZE1WgKgZ9oeICTrov94yQ',
#   'channel_url': 'https://www.youtube.com/channel/UCqZE1WgKgZ9oeICTrov94yQ',
#   'cluster': 19,
#   'cluster_name': 'job, shorts, career, work, iit'},
#  {'channel_id': 'UCqegMHSWfJy1Mp-GCOiu2qA',
#   'channel_url': 'https://www.youtube.com/channel/UCqegMHSWfJy1Mp-GCOiu2qA',
#   'cluster': 19,
#   'cluster_name': 'job, shorts, career, work, iit'},
#  {'channel_id': 'UCqhgi4gWXgt66HGTih1u_6g',
#   'channel_url': 'https://www.youtube.com/channel/UCqhgi4gWXgt66HGTih1u_6g',
#   'cluster': 8,
#   'cluster_name': 'india, sadhguru, google, canada, indian'},
#  {'channel_id': 'UCqvaXJ1K3HheTPNjH-KpwXQ',
#   'channel_url': 'https://www.youtube.com/channel/UCqvaXJ1K3HheTPNjH-KpwXQ',
#   'cluster': 3,
#   'cluster_name': 'bloomberg, news, bitcoin, economy, economics'},
#  {'channel_id': 'UCqwUrj10mAEsqezcItqvwEw',
#   'channel_url': 'https://www.youtube.com/channel/UCqwUrj10mAEsqezcItqvwEw',
#   'cluster': 30,
#   'cluster_name': 'kannada, comedy, funny, vines, prank'},
#  {'channel_id': 'UCr4mZxG-wPWMUn5aLl8q4-Q',
#   'channel_url': 'https://www.youtube.com/channel/UCr4mZxG-wPWMUn5aLl8q4-Q',
#   'cluster': 26,
#   'cluster_name': 'subliminal, affirmations, meditation, mind, hypnosis'},
#  {'channel_id': 'UCr8Xk8otTXckBw2rXEQXMuA',
#   'channel_url': 'https://www.youtube.com/channel/UCr8Xk8otTXckBw2rXEQXMuA',
#   'cluster': 11,
#   'cluster_name': 'prank, shorts, onlyjayus, iphone, vrchat'},
#  {'channel_id': 'UCrC8mOqJQpoB7NuIMKIS6rQ',
#   'channel_url': 'https://www.youtube.com/channel/UCrC8mOqJQpoB7NuIMKIS6rQ',
#   'cluster': 1,
#   'cluster_name': 'india, defence, indian, upsc, ias'},
#  {'channel_id': 'UCrIOuPmqRLVmHKNGldGf2Kw',
#   'channel_url': 'https://www.youtube.com/channel/UCrIOuPmqRLVmHKNGldGf2Kw',
#   'cluster': 26,
#   'cluster_name': 'subliminal, affirmations, meditation, mind, hypnosis'},
#  {'channel_id': 'UCrM7B7SL_g1edFOnmj-SDKg',
#   'channel_url': 'https://www.youtube.com/channel/UCrM7B7SL_g1edFOnmj-SDKg',
#   'cluster': 3,
#   'cluster_name': 'bloomberg, news, bitcoin, economy, economics'},
#  {'channel_id': 'UCra3KQoJlOP7RYwaCyH2qew',
#   'channel_url': 'https://www.youtube.com/channel/UCra3KQoJlOP7RYwaCyH2qew',
#   'cluster': 16,
#   'cluster_name': 'gre, toefl, ielts, test, vocabulary'},
#  {'channel_id': 'UCsDTy8jvHcwMvSZf_JGi-FA',
#   'channel_url': 'https://www.youtube.com/channel/UCsDTy8jvHcwMvSZf_JGi-FA',
#   'cluster': 8,
#   'cluster_name': 'india, sadhguru, google, canada, indian'},
#  {'channel_id': 'UCsEMQbMruJjM4z6C9xFUbsA',
#   'channel_url': 'https://www.youtube.com/channel/UCsEMQbMruJjM4z6C9xFUbsA',
#   'cluster': 8,
#   'cluster_name': 'india, sadhguru, google, canada, indian'},
#  {'channel_id': 'UCsT0YIqwnpJCM-mx7-gSA4Q',
#   'channel_url': 'https://www.youtube.com/channel/UCsT0YIqwnpJCM-mx7-gSA4Q',
#   'cluster': 0,
#   'cluster_name': 'english, study, big, harvard, brown'},
#  {'channel_id': 'UCsTcErHg8oDvUnTzoqsYeNw',
#   'channel_url': 'https://www.youtube.com/channel/UCsTcErHg8oDvUnTzoqsYeNw',
#   'cluster': 11,
#   'cluster_name': 'prank, shorts, onlyjayus, iphone, vrchat'},
#  {'channel_id': 'UCsrKsXEAqCbZyVrCibkgpwQ',
#   'channel_url': 'https://www.youtube.com/channel/UCsrKsXEAqCbZyVrCibkgpwQ',
#   'cluster': 17,
#   'cluster_name': 'shooting, gun, glock, review, ak'},
#  {'channel_id': 'UCsv4YOF2RBYh0NQ1vuHQ-hg',
#   'channel_url': 'https://www.youtube.com/channel/UCsv4YOF2RBYh0NQ1vuHQ-hg',
#   'cluster': 14,
#   'cluster_name': 'comedy, trevor, noah, funny, netflix'},
#  {'channel_id': 'UCt2JXOLNxqry7B_4rRZME3Q',
#   'channel_url': 'https://www.youtube.com/channel/UCt2JXOLNxqry7B_4rRZME3Q',
#   'cluster': 1,
#   'cluster_name': 'india, defence, indian, upsc, ias'},
#  {'channel_id': 'UCtAIs1VCQrymlAnw3mGonhw',
#   'channel_url': 'https://www.youtube.com/channel/UCtAIs1VCQrymlAnw3mGonhw',
#   'cluster': 4,
#   'cluster_name': 'quantum, holes, flammy, integral, interpretation'},
#  {'channel_id': 'UCtYLUTtgS3k1Fg4y5tAhLbw',
#   'channel_url': 'https://www.youtube.com/channel/UCtYLUTtgS3k1Fg4y5tAhLbw',
#   'cluster': 18,
#   'cluster_name': 'data, science, learning, google, tensorflow'},
#  {'channel_id': 'UCtdQmE-3ny-M3twGKmOrTcg',
#   'channel_url': 'https://www.youtube.com/channel/UCtdQmE-3ny-M3twGKmOrTcg',
#   'cluster': 6,
#   'cluster_name': 'music, guitar, berklee, ukulele, flute'},
#  {'channel_id': 'UCteRPiisgIoHtMgqHegpWAQ',
#   'channel_url': 'https://www.youtube.com/channel/UCteRPiisgIoHtMgqHegpWAQ',
#   'cluster': 18,
#   'cluster_name': 'data, science, learning, google, tensorflow'},
#  {'channel_id': 'UCtiqGX-_f8kA0MZkQ4yPJ5g',
#   'channel_url': 'https://www.youtube.com/channel/UCtiqGX-_f8kA0MZkQ4yPJ5g',
#   'cluster': 28,
#   'cluster_name': 'startup, design, entrepreneurship, startups, sales'},
#  {'channel_id': 'UCtyYTpFBzWdoSFx2Gl2VNbQ',
#   'channel_url': 'https://www.youtube.com/channel/UCtyYTpFBzWdoSFx2Gl2VNbQ',
#   'cluster': 33,
#   'cluster_name': 'python, google, dash, software, programming'},
#  {'channel_id': 'UCu4XcDBdnZkV6-5z2f16M0g',
#   'channel_url': 'https://www.youtube.com/channel/UCu4XcDBdnZkV6-5z2f16M0g',
#   'cluster': 15,
#   'cluster_name': 'documentary, telegraph, bbc, tv, news'},
#  {'channel_id': 'UCu57RDCZ_j0lGUX49fT6khA',
#   'channel_url': 'https://www.youtube.com/channel/UCu57RDCZ_j0lGUX49fT6khA',
#   'cluster': 29,
#   'cluster_name': 'healing, attraction, law, shivani, pranic'},
#  {'channel_id': 'UCuDz-AQO2KuXzjtxoycrnJg',
#   'channel_url': 'https://www.youtube.com/channel/UCuDz-AQO2KuXzjtxoycrnJg',
#   'cluster': 11,
#   'cluster_name': 'prank, shorts, onlyjayus, iphone, vrchat'},
#  {'channel_id': 'UCuJ-WNoWSzB-r43ftlr6gZQ',
#   'channel_url': 'https://www.youtube.com/channel/UCuJ-WNoWSzB-r43ftlr6gZQ',
#   'cluster': 0,
#   'cluster_name': 'english, study, big, harvard, brown'},
#  {'channel_id': 'UCuhkaTaUtz9ba_BYWjA_sUA',
#   'channel_url': 'https://www.youtube.com/channel/UCuhkaTaUtz9ba_BYWjA_sUA',
#   'cluster': 30,
#   'cluster_name': 'kannada, comedy, funny, vines, prank'},
#  {'channel_id': 'UCupUfUvPVDKDIbDrSFCniAg',
#   'channel_url': 'https://www.youtube.com/channel/UCupUfUvPVDKDIbDrSFCniAg',
#   'cluster': 18,
#   'cluster_name': 'data, science, learning, google, tensorflow'},
#  {'channel_id': 'UCuzSOy9pzFbdGsn-aSuMJCA',
#   'channel_url': 'https://www.youtube.com/channel/UCuzSOy9pzFbdGsn-aSuMJCA',
#   'cluster': 0,
#   'cluster_name': 'english, study, big, harvard, brown'},
#  {'channel_id': 'UCvAE7ZA69WIT8uJNnNXilIQ',
#   'channel_url': 'https://www.youtube.com/channel/UCvAE7ZA69WIT8uJNnNXilIQ',
#   'cluster': 26,
#   'cluster_name': 'subliminal, affirmations, meditation, mind, hypnosis'},
#  {'channel_id': 'UCvB3solmhqtgDeLpD-yTtfg',
#   'channel_url': 'https://www.youtube.com/channel/UCvB3solmhqtgDeLpD-yTtfg',
#   'cluster': 17,
#   'cluster_name': 'shooting, gun, glock, review, ak'},
#  {'channel_id': 'UCvBGFeXbBrq3W9_0oNLJREQ',
#   'channel_url': 'https://www.youtube.com/channel/UCvBGFeXbBrq3W9_0oNLJREQ',
#   'cluster': 28,
#   'cluster_name': 'startup, design, entrepreneurship, startups, sales'},
#  {'channel_id': 'UCvJJ_dzjViJCoLf5uKUTwoA',
#   'channel_url': 'https://www.youtube.com/channel/UCvJJ_dzjViJCoLf5uKUTwoA',
#   'cluster': 3,
#   'cluster_name': 'bloomberg, news, bitcoin, economy, economics'},
#  {'channel_id': 'UCvQECJukTDE2i6aCoMnS-Vg',
#   'channel_url': 'https://www.youtube.com/channel/UCvQECJukTDE2i6aCoMnS-Vg',
#   'cluster': 0,
#   'cluster_name': 'english, study, big, harvard, brown'},
#  {'channel_id': 'UCvbJKkmSauhJz0FRFd6nuOQ',
#   'channel_url': 'https://www.youtube.com/channel/UCvbJKkmSauhJz0FRFd6nuOQ',
#   'cluster': 12,
#   'cluster_name': 'vending, stradman, cars, collection, machine'},
#  {'channel_id': 'UCvkdpLN1agXoiRWEWTtXqjw',
#   'channel_url': 'https://www.youtube.com/channel/UCvkdpLN1agXoiRWEWTtXqjw',
#   'cluster': 11,
#   'cluster_name': 'prank, shorts, onlyjayus, iphone, vrchat'},
#  {'channel_id': 'UCw4wosjC-DKq95xI5klz92w',
#   'channel_url': 'https://www.youtube.com/channel/UCw4wosjC-DKq95xI5klz92w',
#   'cluster': 1,
#   'cluster_name': 'india, defence, indian, upsc, ias'},
#  {'channel_id': 'UCw62Qa74SJ4NCdWG3jw7Dfw',
#   'channel_url': 'https://www.youtube.com/channel/UCw62Qa74SJ4NCdWG3jw7Dfw',
#   'cluster': 14,
#   'cluster_name': 'comedy, trevor, noah, funny, netflix'},
#  {'channel_id': 'UCwB3HiWejAkml1UZ0Qo2bFg',
#   'channel_url': 'https://www.youtube.com/channel/UCwB3HiWejAkml1UZ0Qo2bFg',
#   'cluster': 28,
#   'cluster_name': 'startup, design, entrepreneurship, startups, sales'},
#  {'channel_id': 'UCwH7ZUuRVucq4CYIcoAyE4w',
#   'channel_url': 'https://www.youtube.com/channel/UCwH7ZUuRVucq4CYIcoAyE4w',
#   'cluster': 18,
#   'cluster_name': 'data, science, learning, google, tensorflow'},
#  {'channel_id': 'UCwWhs_6x42TyRM4Wstoq8HA',
#   'channel_url': 'https://www.youtube.com/channel/UCwWhs_6x42TyRM4Wstoq8HA',
#   'cluster': 14,
#   'cluster_name': 'comedy, trevor, noah, funny, netflix'},
#  {'channel_id': 'UCwqusr8YDwM-3mEYTDeJHzw',
#   'channel_url': 'https://www.youtube.com/channel/UCwqusr8YDwM-3mEYTDeJHzw',
#   'cluster': 21,
#   'cluster_name': 'ukraine, russia, news, tldr, chomsky'},
#  {'channel_id': 'UCx4xrSYSfLATFO9fmPZxeNQ',
#   'channel_url': 'https://www.youtube.com/channel/UCx4xrSYSfLATFO9fmPZxeNQ',
#   'cluster': 2,
#   'cluster_name': 'songs, song, music, cover, mishra'},
#  {'channel_id': 'UCxfgkOMZRGhW3mGqrAFF-cg',
#   'channel_url': 'https://www.youtube.com/channel/UCxfgkOMZRGhW3mGqrAFF-cg',
#   'cluster': 8,
#   'cluster_name': 'india, sadhguru, google, canada, indian'},
#  {'channel_id': 'UCxkqZw7BI-Ta9778vnZnDMA',
#   'channel_url': 'https://www.youtube.com/channel/UCxkqZw7BI-Ta9778vnZnDMA',
#   'cluster': 7,
#   'cluster_name': 'workout, fitness, healthy, calisthenics, dr'},
#  {'channel_id': 'UCxtxloVILDQfbzXnX9iFkQg',
#   'channel_url': 'https://www.youtube.com/channel/UCxtxloVILDQfbzXnX9iFkQg',
#   'cluster': 31,
#   'cluster_name': 'homeopathic, medicine, homeopathy, rsverma, dr'},
#  {'channel_id': 'UCy436qLXlyLqddExVC64auw',
#   'channel_url': 'https://www.youtube.com/channel/UCy436qLXlyLqddExVC64auw',
#   'cluster': 2,
#   'cluster_name': 'songs, song, music, cover, mishra'},
#  {'channel_id': 'UCy5mW8fB24ITiiC0etjLI6w',
#   'channel_url': 'https://www.youtube.com/channel/UCy5mW8fB24ITiiC0etjLI6w',
#   'cluster': 2,
#   'cluster_name': 'songs, song, music, cover, mishra'},
#  {'channel_id': 'UCyI4gi0BtlKiUl6KgtuVIUw',
#   'channel_url': 'https://www.youtube.com/channel/UCyI4gi0BtlKiUl6KgtuVIUw',
#   'cluster': 9,
#   'cluster_name': 'dubai, amish, dignity, nas, zaidalit'},
#  {'channel_id': 'UCydVjjfO74Vr7Scecn1sNAg',
#   'channel_url': 'https://www.youtube.com/channel/UCydVjjfO74Vr7Scecn1sNAg',
#   'cluster': 20,
#   'cluster_name': 'usa, abroad, dallas, student, visa'},
#  {'channel_id': 'UCz8KsDcRFXxzYO4guvCR-LA',
#   'channel_url': 'https://www.youtube.com/channel/UCz8KsDcRFXxzYO4guvCR-LA',
#   'cluster': 27,
#   'cluster_name': 'immigration, card, green, visa, hb'}]
